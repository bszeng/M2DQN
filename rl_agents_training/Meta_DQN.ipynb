# %% [markdown]
# # Meta DQN
# * meta learning rate (metalr) = 0.5
# * task-specific network: 32, 32, 15
# * model = 444444
#
#
# * learner alpha=0.01

# %% [markdown]
# ### import required packages

# %%
##################### import required packages #####################


import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os

import sys
if "../" not in sys.path:
    sys.path.append("../")

from lib.envs.slicing_env import SlicingEnvironment
from lib.agents import medqn 
from lib import utils

matplotlib.style.use('ggplot')

##################### configure the simulation #####################

# set a random seed for reproducibility
np.random.seed(2023)

# number of DRL agent timesteps per episode 
max_episode_timesteps = 100

total_data_episodes = 1

# number of DRL agent episodes (for the sake of better results visulization)
total_episodes = 50

# qlearning or sarsa1
agent_name = 'medqn'

learning_type = 'accelerated'

# sigmoid reward function configurations
c1_volte = 0.5
c2_volte = 10
c1_urllc = 2
c2_urllc = 3
c1_video = 1
c2_video = 7

# q-learning agent configurations
exploration = 'e_greedy' # 'e_greedy' or 'boltzmann'
discount_factor=0.3
alpha=0.1
epsilon=0.9
epsilon_decay=0.9
decay_steps=50

# policy reuse flag
# loaded_qnet='no'

# slicing configurations
# number of users per slice in the following order: VoLTE, Video, URLLC
num_users = [int(46/4), int(46/4), int(8/4)]

poisson_volte = np.full((1, 200), 1)
poisson_video = np.full((1, 200), 1)
poisson_urllc = np.full((1, 200), 1)

max_num_users = [max(poisson_volte[0]), max(poisson_video[0]), max(poisson_urllc[0])]

num_users_poisson = [poisson_video[0], poisson_volte[0], poisson_urllc[0]]

max_size_per_tti = 40
max_num_packets = 0
max_traffic_percentage = 1
num_action_lvls = 15
num_slices = 3
sl_win_size = 40
time_quantum = 1
max_trans_per_tti = 6

# %% [markdown]
# ### generate sample traffic data

# %%
traffic_df = utils.generate_data(max_num_users[0], max_num_users[1], 
                                 max_num_users[2], sl_win_size*max_episode_timesteps)
traffic_df = traffic_df.reset_index(drop=True)

# %% [markdown]
# ## Training phase

# %%
initial_run = True

for i in range(0,16):
    # set the weights of the reward function
    w_volte = utils.get_reward_weights(i)[0]
    w_urllc = utils.get_reward_weights(i)[1]
    w_video = utils.get_reward_weights(i)[2]

    print('i=%d: w_volte %f, w_urllc %f, w_video %f' %(i, w_volte, w_urllc, w_video))

    # initialize the OpenAI gym-compatible environment using the configured simulation parameters
    enviro = SlicingEnvironment(traffic_df, max_num_packets, max_size_per_tti, num_action_lvls, 
                         num_slices, max_episode_timesteps, sl_win_size, time_quantum,total_data_episodes,
                         num_users_poisson, max_traffic_percentage, max_trans_per_tti, w_volte, w_urllc,
                            w_video, c1_volte, c1_urllc, c1_video, c2_volte, c2_urllc, c2_video)

    env = enviro
    
    if initial_run == True:
        ##################### train the basic expert agents from scratch given the configured reward function weights
        qnet,stats = medqn.medqn(env,
                                    num_episodes=total_episodes,
                                    exploration=exploration,
                                    gamma=discount_factor,
                                    lr=alpha,
                                    epsilon=epsilon,
                                    epsilon_decay=epsilon_decay,
                                    decay_steps=decay_steps,
                                    initial_run = initial_run,
                                    qNet=None)
        initial_run = False
        mnet_para = qnet
    else:        
        print('initial run:  %s' %(initial_run))
        qnet,stats = medqn.medqn(env,
                            num_episodes=total_episodes,
                            exploration=exploration,
                            gamma=discount_factor,
                            lr=alpha,
                            epsilon=epsilon,
                            epsilon_decay=epsilon_decay,
                            decay_steps=decay_steps,
                            initial_run = initial_run,
                            qNet = mnet_para)
        mnet_para = qnet        
        
# save training data to file
path = 'saved_models/medqn/'
if not os.path.exists(path):
    os.makedirs(path)

mnet_para_file = path + 'medqn.params_' + \
                str(exploration) +'_'+ \
                str(learning_type) + '_' + \
                str(agent_name)
mnet_para.save_parameters(mnet_para_file)

# %% [markdown]
# ## Adaptation phase

# %%
from mxnet import gluon

def build_net(env, net):
    with net.name_scope():
        net.add(gluon.nn.Dense(32, activation='sigmoid'))
        net.add(gluon.nn.Dense(32, activation='sigmoid'))
        net.add(gluon.nn.Dense(env.action_space.n))
    return net

# %%
# base_path = os.getcwd()+'/saved_models/base/'

# q-learning agent configurations
discount_factor=0.3
alpha=0.01 
epsilon=0.1 
epsilon_decay=0.5 
decay_steps=10 
exploration = 'e_greedy'
initial_run = False

order = 0
for i in range(0,10):
    # set the weights of the learner agent's reward function
    w_volte = utils.get_reward_weights_acc(i, order)[0]
    w_urllc = utils.get_reward_weights_acc(i, order)[1]
    w_video = utils.get_reward_weights_acc(i, order)[2]

    print('i=%d: w_volte %f, w_urllc %f, w_video %f' %(i, w_volte, w_urllc, w_video))

    by_w_volte = 0.22
    by_w_urllc = 0.22
    by_w_video = 0.22

    # initialize the OpenAI gym-compatible environment using the configured simulation parameters
    enviro = SlicingEnvironment(traffic_df, max_num_packets, max_size_per_tti, num_action_lvls, 
                         num_slices, max_episode_timesteps, sl_win_size, time_quantum,total_data_episodes,
                         num_users_poisson, max_traffic_percentage, max_trans_per_tti, w_volte, w_urllc,
                            w_video, c1_volte, c1_urllc, c1_video, c2_volte, c2_urllc, c2_video)

    env = enviro

    mnet_para = build_net(env, gluon.nn.Sequential())
    path = 'saved_models/medqn/'
    mnet_para_file = path + 'medqn.params_' + \
                    str(exploration) +'_'+ \
                    str(learning_type) + '_' + \
                    str(agent_name)
    mnet_para.load_parameters(mnet_para_file)

    qnet,stats = medqn.medqn(env,
                        num_episodes=total_episodes,
                        exploration=exploration,
                        gamma=discount_factor,
                        lr=alpha,
                        epsilon=epsilon,
                        epsilon_decay=epsilon_decay,
                        decay_steps=decay_steps,
                        initial_run = False,
                        qNet = mnet_para)

    # log the trained agents' data
    dictionary = {'config': {'generic': {'max_episode_timesteps': max_episode_timesteps, 'total_episodes': total_episodes,
                         'agent_name': agent_name, 'max_size_per_tti': max_size_per_tti,
                         'max_traffic_percentage': max_traffic_percentage, 'num_action_lvls': num_action_lvls,
                         'num_slices': num_slices, 'sl_win_size': sl_win_size, 'max_trans_per_tti': max_trans_per_tti,
                         'w_volte': w_volte, 'w_urllc': w_urllc, 'w_video': w_video, 'by_w_volte': by_w_volte, 
                         'by_w_urllc': by_w_urllc, 'by_w_video': by_w_video,
                         'c1_volte': c1_volte,'c2_volte': c2_volte, 'c1_urllc': c1_urllc, 'c2_urllc': c2_urllc,
                         'c1_video': c1_video, 'c2_video': c2_video,
                         'learning_type': learning_type},
                         'agent_specific': {'discount_factor': discount_factor, 'alpha': alpha,
                                            'epsilon': epsilon, 'epsilon_decay': epsilon_decay,
                                            'decay_steps': decay_steps}
                        },
              'rewards': {'steps': env.step_rewards, 'episodes': list(stats[1])},
              'KPIs': {'delay': env.total_avg_waiting_times,
                       'throughput': env.total_throughputs, 'finished_throughput': env.finished_throughputs,
                       'remaining_sizes_sum': env.remaining_sizes_sum, 'remaining_sizes': env.remaining_sizes,
                       'remaining_times_sum': env.remaining_times_sum, 'remaining_times': env.remaining_times,
                       'total_p_numbers': env.total_p_numbers, 'done_p_numbers': env.done_p_numbers
                     }}
    # save training data to file
    path = 'saved_models/me_accelerated/'
    if not os.path.exists(path):
        # create a new directory because it does not exist 
        os.makedirs(path)
    file_name = path + str(learning_type) + '_' + str(agent_name) + '_' + \
                str(int(w_volte*100)) + str(int(w_urllc*100)) + str(int(w_video*100)) + '_by_' + \
                str(int(by_w_volte*100)) + str(int(by_w_urllc*100)) + str(int(by_w_video*100)) + '_ep.npy'
    np.save(file_name, dictionary)
# Out:
# i=0: w_volte 0.500000, w_urllc 0.400000, w_video 0.100000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 47,egreedy 0.050000
# eps 1,reward 47,egreedy 0.025000
# eps 2,reward 46,egreedy 0.012500
# eps 3,reward 46,egreedy 0.006250
# eps 4,reward 46,egreedy 0.003125
# eps 5,reward 65,egreedy 0.001563
# eps 6,reward 70,egreedy 0.000781
# eps 7,reward 71,egreedy 0.000391
# eps 8,reward 71,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 71,egreedy 0.000098
# eps 10,reward 71,egreedy 0.000098
# eps 11,reward 71,egreedy 0.000098
# eps 12,reward 71,egreedy 0.000098
# eps 13,reward 71,egreedy 0.000098
# eps 14,reward 71,egreedy 0.000098
# eps 15,reward 71,egreedy 0.000098
# eps 16,reward 71,egreedy 0.000098
# eps 17,reward 71,egreedy 0.000098
# eps 18,reward 71,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 71,egreedy 0.000098
# eps 20,reward 71,egreedy 0.000098
# eps 21,reward 71,egreedy 0.000098
# eps 22,reward 71,egreedy 0.000098
# eps 23,reward 71,egreedy 0.000098
# eps 24,reward 71,egreedy 0.000098
# eps 25,reward 71,egreedy 0.000098
# eps 26,reward 71,egreedy 0.000098
# eps 27,reward 71,egreedy 0.000098
# eps 28,reward 71,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 71,egreedy 0.000098
# eps 30,reward 71,egreedy 0.000098
# eps 31,reward 71,egreedy 0.000098
# eps 32,reward 71,egreedy 0.000098
# eps 33,reward 70,egreedy 0.000098
# eps 34,reward 71,egreedy 0.000098
# eps 35,reward 71,egreedy 0.000098
# eps 36,reward 71,egreedy 0.000098
# eps 37,reward 71,egreedy 0.000098
# eps 38,reward 71,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 71,egreedy 0.000098
# eps 40,reward 71,egreedy 0.000098
# eps 41,reward 71,egreedy 0.000098
# eps 42,reward 71,egreedy 0.000098
# eps 43,reward 70,egreedy 0.000098
# eps 44,reward 71,egreedy 0.000098
# eps 45,reward 71,egreedy 0.000098
# eps 46,reward 68,egreedy 0.000098
# eps 47,reward 69,egreedy 0.000098
# eps 48,reward 65,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 71,egreedy 0.000098
# i=1: w_volte 0.500000, w_urllc 0.100000, w_video 0.400000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 21,egreedy 0.050000
# eps 1,reward 21,egreedy 0.025000
# eps 2,reward 19,egreedy 0.012500
# eps 3,reward 18,egreedy 0.006250
# eps 4,reward 18,egreedy 0.003125
# eps 5,reward 71,egreedy 0.001563
# eps 6,reward 77,egreedy 0.000781
# eps 7,reward 83,egreedy 0.000391
# eps 8,reward 83,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 83,egreedy 0.000098
# eps 10,reward 83,egreedy 0.000098
# eps 11,reward 83,egreedy 0.000098
# eps 12,reward 83,egreedy 0.000098
# eps 13,reward 83,egreedy 0.000098
# eps 14,reward 83,egreedy 0.000098
# eps 15,reward 83,egreedy 0.000098
# eps 16,reward 83,egreedy 0.000098
# eps 17,reward 83,egreedy 0.000098
# eps 18,reward 83,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 83,egreedy 0.000098
# eps 20,reward 83,egreedy 0.000098
# eps 21,reward 83,egreedy 0.000098
# eps 22,reward 83,egreedy 0.000098
# eps 23,reward 83,egreedy 0.000098
# eps 24,reward 83,egreedy 0.000098
# eps 25,reward 83,egreedy 0.000098
# eps 26,reward 83,egreedy 0.000098
# eps 27,reward 83,egreedy 0.000098
# eps 28,reward 83,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 83,egreedy 0.000098
# eps 30,reward 83,egreedy 0.000098
# eps 31,reward 83,egreedy 0.000098
# eps 32,reward 83,egreedy 0.000098
# eps 33,reward 83,egreedy 0.000098
# eps 34,reward 83,egreedy 0.000098
# eps 35,reward 83,egreedy 0.000098
# eps 36,reward 83,egreedy 0.000098
# eps 37,reward 83,egreedy 0.000098
# eps 38,reward 83,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 83,egreedy 0.000098
# eps 40,reward 83,egreedy 0.000098
# eps 41,reward 83,egreedy 0.000098
# eps 42,reward 83,egreedy 0.000098
# eps 43,reward 83,egreedy 0.000098
# eps 44,reward 83,egreedy 0.000098
# eps 45,reward 83,egreedy 0.000098
# eps 46,reward 83,egreedy 0.000098
# eps 47,reward 83,egreedy 0.000098
# eps 48,reward 83,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 83,egreedy 0.000098
# i=2: w_volte 0.100000, w_urllc 0.150000, w_video 0.750000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 18,egreedy 0.050000
# eps 1,reward 16,egreedy 0.025000
# eps 2,reward 16,egreedy 0.012500
# eps 3,reward 16,egreedy 0.006250
# eps 4,reward 16,egreedy 0.003125
# eps 5,reward 65,egreedy 0.001563
# eps 6,reward 74,egreedy 0.000781
# eps 7,reward 77,egreedy 0.000391
# eps 8,reward 79,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 79,egreedy 0.000098
# eps 10,reward 79,egreedy 0.000098
# eps 11,reward 79,egreedy 0.000098
# eps 12,reward 79,egreedy 0.000098
# eps 13,reward 79,egreedy 0.000098
# eps 14,reward 79,egreedy 0.000098
# eps 15,reward 79,egreedy 0.000098
# eps 16,reward 79,egreedy 0.000098
# eps 17,reward 79,egreedy 0.000098
# eps 18,reward 79,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 79,egreedy 0.000098
# eps 20,reward 79,egreedy 0.000098
# eps 21,reward 79,egreedy 0.000098
# eps 22,reward 79,egreedy 0.000098
# eps 23,reward 79,egreedy 0.000098
# eps 24,reward 79,egreedy 0.000098
# eps 25,reward 79,egreedy 0.000098
# eps 26,reward 79,egreedy 0.000098
# eps 27,reward 79,egreedy 0.000098
# eps 28,reward 79,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 79,egreedy 0.000098
# eps 30,reward 79,egreedy 0.000098
# eps 31,reward 79,egreedy 0.000098
# eps 32,reward 79,egreedy 0.000098
# eps 33,reward 79,egreedy 0.000098
# eps 34,reward 79,egreedy 0.000098
# eps 35,reward 79,egreedy 0.000098
# eps 36,reward 79,egreedy 0.000098
# eps 37,reward 79,egreedy 0.000098
# eps 38,reward 79,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 79,egreedy 0.000098
# eps 40,reward 79,egreedy 0.000098
# eps 41,reward 79,egreedy 0.000098
# eps 42,reward 79,egreedy 0.000098
# eps 43,reward 79,egreedy 0.000098
# eps 44,reward 79,egreedy 0.000098
# eps 45,reward 79,egreedy 0.000098
# eps 46,reward 79,egreedy 0.000098
# eps 47,reward 79,egreedy 0.000098
# eps 48,reward 79,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 79,egreedy 0.000098
# i=3: w_volte 0.100000, w_urllc 0.850000, w_video 0.050000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 77,egreedy 0.050000
# eps 1,reward 78,egreedy 0.025000
# eps 2,reward 79,egreedy 0.012500
# eps 3,reward 82,egreedy 0.006250
# eps 4,reward 82,egreedy 0.003125
# eps 5,reward 82,egreedy 0.001563
# eps 6,reward 75,egreedy 0.000781
# eps 7,reward 82,egreedy 0.000391
# eps 8,reward 75,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 81,egreedy 0.000098
# eps 10,reward 82,egreedy 0.000098
# eps 11,reward 82,egreedy 0.000098
# eps 12,reward 82,egreedy 0.000098
# eps 13,reward 82,egreedy 0.000098
# eps 14,reward 82,egreedy 0.000098
# eps 15,reward 82,egreedy 0.000098
# eps 16,reward 82,egreedy 0.000098
# eps 17,reward 82,egreedy 0.000098
# eps 18,reward 82,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 82,egreedy 0.000098
# eps 20,reward 82,egreedy 0.000098
# eps 21,reward 82,egreedy 0.000098
# eps 22,reward 82,egreedy 0.000098
# eps 23,reward 82,egreedy 0.000098
# eps 24,reward 82,egreedy 0.000098
# eps 25,reward 82,egreedy 0.000098
# eps 26,reward 82,egreedy 0.000098
# eps 27,reward 82,egreedy 0.000098
# eps 28,reward 82,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 82,egreedy 0.000098
# eps 30,reward 82,egreedy 0.000098
# eps 31,reward 82,egreedy 0.000098
# eps 32,reward 82,egreedy 0.000098
# eps 33,reward 82,egreedy 0.000098
# eps 34,reward 82,egreedy 0.000098
# eps 35,reward 82,egreedy 0.000098
# eps 36,reward 82,egreedy 0.000098
# eps 37,reward 82,egreedy 0.000098
# eps 38,reward 82,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 82,egreedy 0.000098
# eps 40,reward 82,egreedy 0.000098
# eps 41,reward 82,egreedy 0.000098
# eps 42,reward 82,egreedy 0.000098
# eps 43,reward 82,egreedy 0.000098
# eps 44,reward 82,egreedy 0.000098
# eps 45,reward 82,egreedy 0.000098
# eps 46,reward 83,egreedy 0.000098
# eps 47,reward 84,egreedy 0.000098
# eps 48,reward 85,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 85,egreedy 0.000098
# i=4: w_volte 0.800000, w_urllc 0.150000, w_video 0.050000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 31,egreedy 0.050000
# eps 1,reward 32,egreedy 0.025000
# eps 2,reward 29,egreedy 0.012500
# eps 3,reward 28,egreedy 0.006250
# eps 4,reward 28,egreedy 0.003125
# eps 5,reward 78,egreedy 0.001563
# eps 6,reward 84,egreedy 0.000781
# eps 7,reward 85,egreedy 0.000391
# eps 8,reward 85,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 85,egreedy 0.000098
# eps 10,reward 85,egreedy 0.000098
# eps 11,reward 85,egreedy 0.000098
# eps 12,reward 85,egreedy 0.000098
# eps 13,reward 85,egreedy 0.000098
# eps 14,reward 85,egreedy 0.000098
# eps 15,reward 85,egreedy 0.000098
# eps 16,reward 85,egreedy 0.000098
# eps 17,reward 85,egreedy 0.000098
# eps 18,reward 85,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 85,egreedy 0.000098
# eps 20,reward 85,egreedy 0.000098
# eps 21,reward 85,egreedy 0.000098
# eps 22,reward 85,egreedy 0.000098
# eps 23,reward 85,egreedy 0.000098
# eps 24,reward 85,egreedy 0.000098
# eps 25,reward 85,egreedy 0.000098
# eps 26,reward 85,egreedy 0.000098
# eps 27,reward 85,egreedy 0.000098
# eps 28,reward 85,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 85,egreedy 0.000098
# eps 30,reward 85,egreedy 0.000098
# eps 31,reward 85,egreedy 0.000098
# eps 32,reward 85,egreedy 0.000098
# eps 33,reward 85,egreedy 0.000098
# eps 34,reward 85,egreedy 0.000098
# eps 35,reward 85,egreedy 0.000098
# eps 36,reward 85,egreedy 0.000098
# eps 37,reward 85,egreedy 0.000098
# eps 38,reward 85,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 85,egreedy 0.000098
# eps 40,reward 84,egreedy 0.000098
# eps 41,reward 85,egreedy 0.000098
# eps 42,reward 84,egreedy 0.000098
# eps 43,reward 85,egreedy 0.000098
# eps 44,reward 84,egreedy 0.000098
# eps 45,reward 85,egreedy 0.000098
# eps 46,reward 85,egreedy 0.000098
# eps 47,reward 85,egreedy 0.000098
# eps 48,reward 85,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 85,egreedy 0.000098
# i=5: w_volte 0.600000, w_urllc 0.250000, w_video 0.150000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 36,egreedy 0.050000
# eps 1,reward 36,egreedy 0.025000
# eps 2,reward 34,egreedy 0.012500
# eps 3,reward 34,egreedy 0.006250
# eps 4,reward 34,egreedy 0.003125
# eps 5,reward 67,egreedy 0.001563
# eps 6,reward 71,egreedy 0.000781
# eps 7,reward 71,egreedy 0.000391
# eps 8,reward 72,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 71,egreedy 0.000098
# eps 10,reward 71,egreedy 0.000098
# eps 11,reward 71,egreedy 0.000098
# eps 12,reward 71,egreedy 0.000098
# eps 13,reward 71,egreedy 0.000098
# eps 14,reward 71,egreedy 0.000098
# eps 15,reward 72,egreedy 0.000098
# eps 16,reward 71,egreedy 0.000098
# eps 17,reward 71,egreedy 0.000098
# eps 18,reward 72,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 71,egreedy 0.000098
# eps 20,reward 72,egreedy 0.000098
# eps 21,reward 72,egreedy 0.000098
# eps 22,reward 72,egreedy 0.000098
# eps 23,reward 71,egreedy 0.000098
# eps 24,reward 71,egreedy 0.000098
# eps 25,reward 72,egreedy 0.000098
# eps 26,reward 71,egreedy 0.000098
# eps 27,reward 71,egreedy 0.000098
# eps 28,reward 71,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 72,egreedy 0.000098
# eps 30,reward 71,egreedy 0.000098
# eps 31,reward 71,egreedy 0.000098
# eps 32,reward 72,egreedy 0.000098
# eps 33,reward 71,egreedy 0.000098
# eps 34,reward 71,egreedy 0.000098
# eps 35,reward 71,egreedy 0.000098
# eps 36,reward 71,egreedy 0.000098
# eps 37,reward 71,egreedy 0.000098
# eps 38,reward 71,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 71,egreedy 0.000098
# eps 40,reward 71,egreedy 0.000098
# eps 41,reward 71,egreedy 0.000098
# eps 42,reward 72,egreedy 0.000098
# eps 43,reward 71,egreedy 0.000098
# eps 44,reward 72,egreedy 0.000098
# eps 45,reward 71,egreedy 0.000098
# eps 46,reward 71,egreedy 0.000098
# eps 47,reward 71,egreedy 0.000098
# eps 48,reward 71,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 72,egreedy 0.000098
# i=6: w_volte 0.200000, w_urllc 0.550000, w_video 0.250000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 53,egreedy 0.050000
# eps 1,reward 54,egreedy 0.025000
# eps 2,reward 54,egreedy 0.012500
# eps 3,reward 55,egreedy 0.006250
# eps 4,reward 55,egreedy 0.003125
# eps 5,reward 50,egreedy 0.001563
# eps 6,reward 54,egreedy 0.000781
# eps 7,reward 51,egreedy 0.000391
# eps 8,reward 55,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 55,egreedy 0.000098
# eps 10,reward 55,egreedy 0.000098
# eps 11,reward 55,egreedy 0.000098
# eps 12,reward 55,egreedy 0.000098
# eps 13,reward 55,egreedy 0.000098
# eps 14,reward 55,egreedy 0.000098
# eps 15,reward 55,egreedy 0.000098
# eps 16,reward 54,egreedy 0.000098
# eps 17,reward 55,egreedy 0.000098
# eps 18,reward 55,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 55,egreedy 0.000098
# eps 20,reward 55,egreedy 0.000098
# eps 21,reward 54,egreedy 0.000098
# eps 22,reward 55,egreedy 0.000098
# eps 23,reward 55,egreedy 0.000098
# eps 24,reward 55,egreedy 0.000098
# eps 25,reward 54,egreedy 0.000098
# eps 26,reward 55,egreedy 0.000098
# eps 27,reward 54,egreedy 0.000098
# eps 28,reward 55,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 55,egreedy 0.000098
# eps 30,reward 54,egreedy 0.000098
# eps 31,reward 55,egreedy 0.000098
# eps 32,reward 54,egreedy 0.000098
# eps 33,reward 55,egreedy 0.000098
# eps 34,reward 55,egreedy 0.000098
# eps 35,reward 55,egreedy 0.000098
# eps 36,reward 55,egreedy 0.000098
# eps 37,reward 55,egreedy 0.000098
# eps 38,reward 55,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 54,egreedy 0.000098
# eps 40,reward 54,egreedy 0.000098
# eps 41,reward 55,egreedy 0.000098
# eps 42,reward 55,egreedy 0.000098
# eps 43,reward 54,egreedy 0.000098
# eps 44,reward 55,egreedy 0.000098
# eps 45,reward 54,egreedy 0.000098
# eps 46,reward 55,egreedy 0.000098
# eps 47,reward 55,egreedy 0.000098
# eps 48,reward 54,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 55,egreedy 0.000098
# i=7: w_volte 0.200000, w_urllc 0.250000, w_video 0.550000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 28,egreedy 0.050000
# eps 1,reward 27,egreedy 0.025000
# eps 2,reward 27,egreedy 0.012500
# eps 3,reward 27,egreedy 0.006250
# eps 4,reward 27,egreedy 0.003125
# eps 5,reward 61,egreedy 0.001563
# eps 6,reward 67,egreedy 0.000781
# eps 7,reward 67,egreedy 0.000391
# eps 8,reward 67,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 67,egreedy 0.000098
# eps 10,reward 67,egreedy 0.000098
# eps 11,reward 67,egreedy 0.000098
# eps 12,reward 67,egreedy 0.000098
# eps 13,reward 67,egreedy 0.000098
# eps 14,reward 67,egreedy 0.000098
# eps 15,reward 67,egreedy 0.000098
# eps 16,reward 67,egreedy 0.000098
# eps 17,reward 67,egreedy 0.000098
# eps 18,reward 67,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 67,egreedy 0.000098
# eps 20,reward 67,egreedy 0.000098
# eps 21,reward 67,egreedy 0.000098
# eps 22,reward 67,egreedy 0.000098
# eps 23,reward 67,egreedy 0.000098
# eps 24,reward 67,egreedy 0.000098
# eps 25,reward 67,egreedy 0.000098
# eps 26,reward 67,egreedy 0.000098
# eps 27,reward 67,egreedy 0.000098
# eps 28,reward 67,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 67,egreedy 0.000098
# eps 30,reward 67,egreedy 0.000098
# eps 31,reward 67,egreedy 0.000098
# eps 32,reward 67,egreedy 0.000098
# eps 33,reward 67,egreedy 0.000098
# eps 34,reward 67,egreedy 0.000098
# eps 35,reward 67,egreedy 0.000098
# eps 36,reward 67,egreedy 0.000098
# eps 37,reward 67,egreedy 0.000098
# eps 38,reward 67,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 67,egreedy 0.000098
# eps 40,reward 67,egreedy 0.000098
# eps 41,reward 67,egreedy 0.000098
# eps 42,reward 67,egreedy 0.000098
# eps 43,reward 67,egreedy 0.000098
# eps 44,reward 67,egreedy 0.000098
# eps 45,reward 67,egreedy 0.000098
# eps 46,reward 67,egreedy 0.000098
# eps 47,reward 67,egreedy 0.000098
# eps 48,reward 67,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 67,egreedy 0.000098
# i=8: w_volte 0.400000, w_urllc 0.350000, w_video 0.250000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 40,egreedy 0.050000
# eps 1,reward 40,egreedy 0.025000
# eps 2,reward 40,egreedy 0.012500
# eps 3,reward 40,egreedy 0.006250
# eps 4,reward 40,egreedy 0.003125
# eps 5,reward 57,egreedy 0.001563
# eps 6,reward 60,egreedy 0.000781
# eps 7,reward 60,egreedy 0.000391
# eps 8,reward 61,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 60,egreedy 0.000098
# eps 10,reward 61,egreedy 0.000098
# eps 11,reward 61,egreedy 0.000098
# eps 12,reward 61,egreedy 0.000098
# eps 13,reward 60,egreedy 0.000098
# eps 14,reward 61,egreedy 0.000098
# eps 15,reward 61,egreedy 0.000098
# eps 16,reward 60,egreedy 0.000098
# eps 17,reward 60,egreedy 0.000098
# eps 18,reward 61,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 61,egreedy 0.000098
# eps 20,reward 61,egreedy 0.000098
# eps 21,reward 61,egreedy 0.000098
# eps 22,reward 61,egreedy 0.000098
# eps 23,reward 61,egreedy 0.000098
# eps 24,reward 61,egreedy 0.000098
# eps 25,reward 61,egreedy 0.000098
# eps 26,reward 61,egreedy 0.000098
# eps 27,reward 60,egreedy 0.000098
# eps 28,reward 60,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 60,egreedy 0.000098
# eps 30,reward 60,egreedy 0.000098
# eps 31,reward 61,egreedy 0.000098
# eps 32,reward 61,egreedy 0.000098
# eps 33,reward 61,egreedy 0.000098
# eps 34,reward 61,egreedy 0.000098
# eps 35,reward 60,egreedy 0.000098
# eps 36,reward 61,egreedy 0.000098
# eps 37,reward 61,egreedy 0.000098
# eps 38,reward 60,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 61,egreedy 0.000098
# eps 40,reward 61,egreedy 0.000098
# eps 41,reward 63,egreedy 0.000098
# eps 42,reward 66,egreedy 0.000098
# eps 43,reward 65,egreedy 0.000098
# eps 44,reward 66,egreedy 0.000098
# eps 45,reward 66,egreedy 0.000098
# eps 46,reward 66,egreedy 0.000098
# eps 47,reward 66,egreedy 0.000098
# eps 48,reward 66,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 65,egreedy 0.000098
# i=9: w_volte 0.300000, w_urllc 0.450000, w_video 0.250000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 47,egreedy 0.050000
# eps 1,reward 47,egreedy 0.025000
# eps 2,reward 47,egreedy 0.012500
# eps 3,reward 48,egreedy 0.006250
# eps 4,reward 48,egreedy 0.003125
# eps 5,reward 53,egreedy 0.001563
# eps 6,reward 54,egreedy 0.000781
# eps 7,reward 55,egreedy 0.000391
# eps 8,reward 54,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 54,egreedy 0.000098
# eps 10,reward 55,egreedy 0.000098
# eps 11,reward 55,egreedy 0.000098
# eps 12,reward 55,egreedy 0.000098
# eps 13,reward 55,egreedy 0.000098
# eps 14,reward 56,egreedy 0.000098
# eps 15,reward 55,egreedy 0.000098
# eps 16,reward 55,egreedy 0.000098
# eps 17,reward 55,egreedy 0.000098
# eps 18,reward 54,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 56,egreedy 0.000098
# eps 20,reward 55,egreedy 0.000098
# eps 21,reward 55,egreedy 0.000098
# eps 22,reward 55,egreedy 0.000098
# eps 23,reward 56,egreedy 0.000098
# eps 24,reward 55,egreedy 0.000098
# eps 25,reward 56,egreedy 0.000098
# eps 26,reward 55,egreedy 0.000098
# eps 27,reward 56,egreedy 0.000098
# eps 28,reward 55,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 56,egreedy 0.000098
# eps 30,reward 55,egreedy 0.000098
# eps 31,reward 55,egreedy 0.000098
# eps 32,reward 55,egreedy 0.000098
# eps 33,reward 54,egreedy 0.000098
# eps 34,reward 55,egreedy 0.000098
# eps 35,reward 55,egreedy 0.000098
# eps 36,reward 55,egreedy 0.000098
# eps 37,reward 55,egreedy 0.000098
# eps 38,reward 55,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 55,egreedy 0.000098
# eps 40,reward 55,egreedy 0.000098
# eps 41,reward 55,egreedy 0.000098
# eps 42,reward 52,egreedy 0.000098
# eps 43,reward 59,egreedy 0.000098
# eps 44,reward 60,egreedy 0.000098
# eps 45,reward 61,egreedy 0.000098
# eps 46,reward 61,egreedy 0.000098
# eps 47,reward 61,egreedy 0.000098
# eps 48,reward 61,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 61,egreedy 0.000098
# i=0: w_volte 0.300000, w_urllc 0.350000, w_video 0.350000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 38,egreedy 0.050000
# eps 1,reward 38,egreedy 0.025000
# eps 2,reward 38,egreedy 0.012500
# eps 3,reward 38,egreedy 0.006250
# eps 4,reward 38,egreedy 0.003125
# eps 5,reward 55,egreedy 0.001563
# eps 6,reward 59,egreedy 0.000781
# eps 7,reward 59,egreedy 0.000391
# eps 8,reward 59,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 59,egreedy 0.000098
# eps 10,reward 59,egreedy 0.000098
# eps 11,reward 59,egreedy 0.000098
# eps 12,reward 58,egreedy 0.000098
# eps 13,reward 59,egreedy 0.000098
# eps 14,reward 59,egreedy 0.000098
# eps 15,reward 59,egreedy 0.000098
# eps 16,reward 59,egreedy 0.000098
# eps 17,reward 59,egreedy 0.000098
# eps 18,reward 58,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 59,egreedy 0.000098
# eps 20,reward 59,egreedy 0.000098
# eps 21,reward 59,egreedy 0.000098
# eps 22,reward 59,egreedy 0.000098
# eps 23,reward 59,egreedy 0.000098
# eps 24,reward 59,egreedy 0.000098
# eps 25,reward 59,egreedy 0.000098
# eps 26,reward 59,egreedy 0.000098
# eps 27,reward 59,egreedy 0.000098
# eps 28,reward 59,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 59,egreedy 0.000098
# eps 30,reward 59,egreedy 0.000098
# eps 31,reward 59,egreedy 0.000098
# eps 32,reward 59,egreedy 0.000098
# eps 33,reward 59,egreedy 0.000098
# eps 34,reward 59,egreedy 0.000098
# eps 35,reward 59,egreedy 0.000098
# eps 36,reward 59,egreedy 0.000098
# eps 37,reward 59,egreedy 0.000098
# eps 38,reward 59,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 59,egreedy 0.000098
# eps 40,reward 59,egreedy 0.000098
# eps 41,reward 59,egreedy 0.000098
# eps 42,reward 59,egreedy 0.000098
# eps 43,reward 59,egreedy 0.000098
# eps 44,reward 59,egreedy 0.000098
# eps 45,reward 59,egreedy 0.000098
# eps 46,reward 59,egreedy 0.000098
# eps 47,reward 59,egreedy 0.000098
# eps 48,reward 59,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 59,egreedy 0.000098
# i=1: w_volte 0.200000, w_urllc 0.450000, w_video 0.350000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 45,egreedy 0.050000
# eps 1,reward 45,egreedy 0.025000
# eps 2,reward 45,egreedy 0.012500
# eps 3,reward 46,egreedy 0.006250
# eps 4,reward 46,egreedy 0.003125
# eps 5,reward 46,egreedy 0.001563
# eps 6,reward 50,egreedy 0.000781
# eps 7,reward 50,egreedy 0.000391
# eps 8,reward 51,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 46,egreedy 0.000098
# eps 10,reward 51,egreedy 0.000098
# eps 11,reward 51,egreedy 0.000098
# eps 12,reward 50,egreedy 0.000098
# eps 13,reward 50,egreedy 0.000098
# eps 14,reward 51,egreedy 0.000098
# eps 15,reward 51,egreedy 0.000098
# eps 16,reward 51,egreedy 0.000098
# eps 17,reward 51,egreedy 0.000098
# eps 18,reward 51,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 49,egreedy 0.000098
# eps 20,reward 50,egreedy 0.000098
# eps 21,reward 50,egreedy 0.000098
# eps 22,reward 49,egreedy 0.000098
# eps 23,reward 50,egreedy 0.000098
# eps 24,reward 50,egreedy 0.000098
# eps 25,reward 51,egreedy 0.000098
# eps 26,reward 49,egreedy 0.000098
# eps 27,reward 50,egreedy 0.000098
# eps 28,reward 50,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 51,egreedy 0.000098
# eps 30,reward 51,egreedy 0.000098
# eps 31,reward 51,egreedy 0.000098
# eps 32,reward 50,egreedy 0.000098
# eps 33,reward 50,egreedy 0.000098
# eps 34,reward 53,egreedy 0.000098
# eps 35,reward 55,egreedy 0.000098
# eps 36,reward 55,egreedy 0.000098
# eps 37,reward 55,egreedy 0.000098
# eps 38,reward 55,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 55,egreedy 0.000098
# eps 40,reward 55,egreedy 0.000098
# eps 41,reward 55,egreedy 0.000098
# eps 42,reward 55,egreedy 0.000098
# eps 43,reward 55,egreedy 0.000098
# eps 44,reward 55,egreedy 0.000098
# eps 45,reward 55,egreedy 0.000098
# eps 46,reward 55,egreedy 0.000098
# eps 47,reward 55,egreedy 0.000098
# eps 48,reward 55,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 55,egreedy 0.000098
# i=2: w_volte 0.400000, w_urllc 0.250000, w_video 0.350000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 32,egreedy 0.050000
# eps 1,reward 32,egreedy 0.025000
# eps 2,reward 31,egreedy 0.012500
# eps 3,reward 30,egreedy 0.006250
# eps 4,reward 30,egreedy 0.003125
# eps 5,reward 63,egreedy 0.001563
# eps 6,reward 69,egreedy 0.000781
# eps 7,reward 69,egreedy 0.000391
# eps 8,reward 69,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 69,egreedy 0.000098
# eps 10,reward 69,egreedy 0.000098
# eps 11,reward 69,egreedy 0.000098
# eps 12,reward 69,egreedy 0.000098
# eps 13,reward 69,egreedy 0.000098
# eps 14,reward 69,egreedy 0.000098
# eps 15,reward 69,egreedy 0.000098
# eps 16,reward 69,egreedy 0.000098
# eps 17,reward 69,egreedy 0.000098
# eps 18,reward 69,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 69,egreedy 0.000098
# eps 20,reward 69,egreedy 0.000098
# eps 21,reward 69,egreedy 0.000098
# eps 22,reward 69,egreedy 0.000098
# eps 23,reward 69,egreedy 0.000098
# eps 24,reward 69,egreedy 0.000098
# eps 25,reward 69,egreedy 0.000098
# eps 26,reward 69,egreedy 0.000098
# eps 27,reward 69,egreedy 0.000098
# eps 28,reward 69,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 69,egreedy 0.000098
# eps 30,reward 69,egreedy 0.000098
# eps 31,reward 69,egreedy 0.000098
# eps 32,reward 69,egreedy 0.000098
# eps 33,reward 68,egreedy 0.000098
# eps 34,reward 69,egreedy 0.000098
# eps 35,reward 69,egreedy 0.000098
# eps 36,reward 66,egreedy 0.000098
# eps 37,reward 69,egreedy 0.000098
# eps 38,reward 69,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 69,egreedy 0.000098
# eps 40,reward 69,egreedy 0.000098
# eps 41,reward 69,egreedy 0.000098
# eps 42,reward 69,egreedy 0.000098
# eps 43,reward 69,egreedy 0.000098
# eps 44,reward 69,egreedy 0.000098
# eps 45,reward 69,egreedy 0.000098
# eps 46,reward 69,egreedy 0.000098
# eps 47,reward 69,egreedy 0.000098
# eps 48,reward 69,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 69,egreedy 0.000098
# i=3: w_volte 0.400000, w_urllc 0.450000, w_video 0.150000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 49,egreedy 0.050000
# eps 1,reward 49,egreedy 0.025000
# eps 2,reward 49,egreedy 0.012500
# eps 3,reward 49,egreedy 0.006250
# eps 4,reward 49,egreedy 0.003125
# eps 5,reward 59,egreedy 0.001563
# eps 6,reward 64,egreedy 0.000781
# eps 7,reward 65,egreedy 0.000391
# eps 8,reward 65,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 65,egreedy 0.000098
# eps 10,reward 65,egreedy 0.000098
# eps 11,reward 65,egreedy 0.000098
# eps 12,reward 65,egreedy 0.000098
# eps 13,reward 65,egreedy 0.000098
# eps 14,reward 65,egreedy 0.000098
# eps 15,reward 65,egreedy 0.000098
# eps 16,reward 64,egreedy 0.000098
# eps 17,reward 64,egreedy 0.000098
# eps 18,reward 65,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 64,egreedy 0.000098
# eps 20,reward 65,egreedy 0.000098
# eps 21,reward 65,egreedy 0.000098
# eps 22,reward 65,egreedy 0.000098
# eps 23,reward 65,egreedy 0.000098
# eps 24,reward 65,egreedy 0.000098
# eps 25,reward 64,egreedy 0.000098
# eps 26,reward 65,egreedy 0.000098
# eps 27,reward 65,egreedy 0.000098
# eps 28,reward 65,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 65,egreedy 0.000098
# eps 30,reward 64,egreedy 0.000098
# eps 31,reward 65,egreedy 0.000098
# eps 32,reward 65,egreedy 0.000098
# eps 33,reward 65,egreedy 0.000098
# eps 34,reward 65,egreedy 0.000098
# eps 35,reward 65,egreedy 0.000098
# eps 36,reward 65,egreedy 0.000098
# eps 37,reward 65,egreedy 0.000098
# eps 38,reward 65,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 65,egreedy 0.000098
# eps 40,reward 65,egreedy 0.000098
# eps 41,reward 65,egreedy 0.000098
# eps 42,reward 65,egreedy 0.000098
# eps 43,reward 65,egreedy 0.000098
# eps 44,reward 59,egreedy 0.000098
# eps 45,reward 65,egreedy 0.000098
# eps 46,reward 64,egreedy 0.000098
# eps 47,reward 65,egreedy 0.000098
# eps 48,reward 65,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 63,egreedy 0.000098
# i=4: w_volte 0.100000, w_urllc 0.250000, w_video 0.650000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 26,egreedy 0.050000
# eps 1,reward 25,egreedy 0.025000
# eps 2,reward 25,egreedy 0.012500
# eps 3,reward 25,egreedy 0.006250
# eps 4,reward 25,egreedy 0.003125
# eps 5,reward 59,egreedy 0.001563
# eps 6,reward 66,egreedy 0.000781
# eps 7,reward 71,egreedy 0.000391
# eps 8,reward 71,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 71,egreedy 0.000098
# eps 10,reward 71,egreedy 0.000098
# eps 11,reward 71,egreedy 0.000098
# eps 12,reward 71,egreedy 0.000098
# eps 13,reward 71,egreedy 0.000098
# eps 14,reward 71,egreedy 0.000098
# eps 15,reward 71,egreedy 0.000098
# eps 16,reward 71,egreedy 0.000098
# eps 17,reward 71,egreedy 0.000098
# eps 18,reward 71,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 71,egreedy 0.000098
# eps 20,reward 71,egreedy 0.000098
# eps 21,reward 71,egreedy 0.000098
# eps 22,reward 71,egreedy 0.000098
# eps 23,reward 71,egreedy 0.000098
# eps 24,reward 71,egreedy 0.000098
# eps 25,reward 71,egreedy 0.000098
# eps 26,reward 71,egreedy 0.000098
# eps 27,reward 71,egreedy 0.000098
# eps 28,reward 71,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 71,egreedy 0.000098
# eps 30,reward 71,egreedy 0.000098
# eps 31,reward 71,egreedy 0.000098
# eps 32,reward 71,egreedy 0.000098
# eps 33,reward 71,egreedy 0.000098
# eps 34,reward 71,egreedy 0.000098
# eps 35,reward 71,egreedy 0.000098
# eps 36,reward 71,egreedy 0.000098
# eps 37,reward 71,egreedy 0.000098
# eps 38,reward 71,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 71,egreedy 0.000098
# eps 40,reward 71,egreedy 0.000098
# eps 41,reward 71,egreedy 0.000098
# eps 42,reward 71,egreedy 0.000098
# eps 43,reward 71,egreedy 0.000098
# eps 44,reward 71,egreedy 0.000098
# eps 45,reward 71,egreedy 0.000098
# eps 46,reward 71,egreedy 0.000098
# eps 47,reward 71,egreedy 0.000098
# eps 48,reward 71,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 71,egreedy 0.000098
# i=5: w_volte 0.100000, w_urllc 0.750000, w_video 0.150000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 68,egreedy 0.050000
# eps 1,reward 69,egreedy 0.025000
# eps 2,reward 70,egreedy 0.012500
# eps 3,reward 72,egreedy 0.006250
# eps 4,reward 72,egreedy 0.003125
# eps 5,reward 71,egreedy 0.001563
# eps 6,reward 70,egreedy 0.000781
# eps 7,reward 72,egreedy 0.000391
# eps 8,reward 65,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 72,egreedy 0.000098
# eps 10,reward 72,egreedy 0.000098
# eps 11,reward 72,egreedy 0.000098
# eps 12,reward 72,egreedy 0.000098
# eps 13,reward 72,egreedy 0.000098
# eps 14,reward 72,egreedy 0.000098
# eps 15,reward 72,egreedy 0.000098
# eps 16,reward 72,egreedy 0.000098
# eps 17,reward 72,egreedy 0.000098
# eps 18,reward 72,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 72,egreedy 0.000098
# eps 20,reward 72,egreedy 0.000098
# eps 21,reward 72,egreedy 0.000098
# eps 22,reward 72,egreedy 0.000098
# eps 23,reward 72,egreedy 0.000098
# eps 24,reward 72,egreedy 0.000098
# eps 25,reward 72,egreedy 0.000098
# eps 26,reward 72,egreedy 0.000098
# eps 27,reward 72,egreedy 0.000098
# eps 28,reward 72,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 72,egreedy 0.000098
# eps 30,reward 72,egreedy 0.000098
# eps 31,reward 72,egreedy 0.000098
# eps 32,reward 72,egreedy 0.000098
# eps 33,reward 72,egreedy 0.000098
# eps 34,reward 72,egreedy 0.000098
# eps 35,reward 72,egreedy 0.000098
# eps 36,reward 72,egreedy 0.000098
# eps 37,reward 72,egreedy 0.000098
# eps 38,reward 72,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 72,egreedy 0.000098
# eps 40,reward 72,egreedy 0.000098
# eps 41,reward 72,egreedy 0.000098
# eps 42,reward 72,egreedy 0.000098
# eps 43,reward 72,egreedy 0.000098
# eps 44,reward 72,egreedy 0.000098
# eps 45,reward 72,egreedy 0.000098
# eps 46,reward 63,egreedy 0.000098
# eps 47,reward 72,egreedy 0.000098
# eps 48,reward 72,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 72,egreedy 0.000098
# i=6: w_volte 0.200000, w_urllc 0.150000, w_video 0.650000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 20,egreedy 0.050000
# eps 1,reward 18,egreedy 0.025000
# eps 2,reward 18,egreedy 0.012500
# eps 3,reward 17,egreedy 0.006250
# eps 4,reward 17,egreedy 0.003125
# eps 5,reward 64,egreedy 0.001563
# eps 6,reward 75,egreedy 0.000781
# eps 7,reward 75,egreedy 0.000391
# eps 8,reward 75,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 75,egreedy 0.000098
# eps 10,reward 75,egreedy 0.000098
# eps 11,reward 75,egreedy 0.000098
# eps 12,reward 75,egreedy 0.000098
# eps 13,reward 75,egreedy 0.000098
# eps 14,reward 75,egreedy 0.000098
# eps 15,reward 75,egreedy 0.000098
# eps 16,reward 75,egreedy 0.000098
# eps 17,reward 75,egreedy 0.000098
# eps 18,reward 75,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 75,egreedy 0.000098
# eps 20,reward 75,egreedy 0.000098
# eps 21,reward 75,egreedy 0.000098
# eps 22,reward 75,egreedy 0.000098
# eps 23,reward 75,egreedy 0.000098
# eps 24,reward 75,egreedy 0.000098
# eps 25,reward 75,egreedy 0.000098
# eps 26,reward 75,egreedy 0.000098
# eps 27,reward 75,egreedy 0.000098
# eps 28,reward 75,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 75,egreedy 0.000098
# eps 30,reward 75,egreedy 0.000098
# eps 31,reward 75,egreedy 0.000098
# eps 32,reward 75,egreedy 0.000098
# eps 33,reward 75,egreedy 0.000098
# eps 34,reward 75,egreedy 0.000098
# eps 35,reward 75,egreedy 0.000098
# eps 36,reward 75,egreedy 0.000098
# eps 37,reward 75,egreedy 0.000098
# eps 38,reward 75,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 75,egreedy 0.000098
# eps 40,reward 75,egreedy 0.000098
# eps 41,reward 75,egreedy 0.000098
# eps 42,reward 75,egreedy 0.000098
# eps 43,reward 75,egreedy 0.000098
# eps 44,reward 75,egreedy 0.000098
# eps 45,reward 75,egreedy 0.000098
# eps 46,reward 75,egreedy 0.000098
# eps 47,reward 75,egreedy 0.000098
# eps 48,reward 75,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 75,egreedy 0.000098
# i=7: w_volte 0.200000, w_urllc 0.750000, w_video 0.050000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 70,egreedy 0.050000
# eps 1,reward 71,egreedy 0.025000
# eps 2,reward 72,egreedy 0.012500
# eps 3,reward 74,egreedy 0.006250
# eps 4,reward 74,egreedy 0.003125
# eps 5,reward 73,egreedy 0.001563
# eps 6,reward 72,egreedy 0.000781
# eps 7,reward 72,egreedy 0.000391
# eps 8,reward 72,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 74,egreedy 0.000098
# eps 10,reward 74,egreedy 0.000098
# eps 11,reward 74,egreedy 0.000098
# eps 12,reward 74,egreedy 0.000098
# eps 13,reward 74,egreedy 0.000098
# eps 14,reward 74,egreedy 0.000098
# eps 15,reward 74,egreedy 0.000098
# eps 16,reward 74,egreedy 0.000098
# eps 17,reward 74,egreedy 0.000098
# eps 18,reward 74,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 74,egreedy 0.000098
# eps 20,reward 74,egreedy 0.000098
# eps 21,reward 74,egreedy 0.000098
# eps 22,reward 74,egreedy 0.000098
# eps 23,reward 74,egreedy 0.000098
# eps 24,reward 74,egreedy 0.000098
# eps 25,reward 72,egreedy 0.000098
# eps 26,reward 74,egreedy 0.000098
# eps 27,reward 74,egreedy 0.000098
# eps 28,reward 74,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 74,egreedy 0.000098
# eps 30,reward 74,egreedy 0.000098
# eps 31,reward 74,egreedy 0.000098
# eps 32,reward 74,egreedy 0.000098
# eps 33,reward 74,egreedy 0.000098
# eps 34,reward 74,egreedy 0.000098
# eps 35,reward 74,egreedy 0.000098
# eps 36,reward 74,egreedy 0.000098
# eps 37,reward 74,egreedy 0.000098
# eps 38,reward 74,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 75,egreedy 0.000098
# eps 40,reward 74,egreedy 0.000098
# eps 41,reward 77,egreedy 0.000098
# eps 42,reward 80,egreedy 0.000098
# eps 43,reward 80,egreedy 0.000098
# eps 44,reward 80,egreedy 0.000098
# eps 45,reward 80,egreedy 0.000098
# eps 46,reward 80,egreedy 0.000098
# eps 47,reward 80,egreedy 0.000098
# eps 48,reward 80,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 80,egreedy 0.000098
# i=8: w_volte 0.700000, w_urllc 0.250000, w_video 0.050000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 38,egreedy 0.050000
# eps 1,reward 38,egreedy 0.025000
# eps 2,reward 36,egreedy 0.012500
# eps 3,reward 36,egreedy 0.006250
# eps 4,reward 36,egreedy 0.003125
# eps 5,reward 72,egreedy 0.001563
# eps 6,reward 81,egreedy 0.000781
# eps 7,reward 81,egreedy 0.000391
# eps 8,reward 81,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 81,egreedy 0.000098
# eps 10,reward 80,egreedy 0.000098
# eps 11,reward 81,egreedy 0.000098
# eps 12,reward 80,egreedy 0.000098
# eps 13,reward 81,egreedy 0.000098
# eps 14,reward 80,egreedy 0.000098
# eps 15,reward 81,egreedy 0.000098
# eps 16,reward 80,egreedy 0.000098
# eps 17,reward 80,egreedy 0.000098
# eps 18,reward 80,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 80,egreedy 0.000098
# eps 20,reward 81,egreedy 0.000098
# eps 21,reward 79,egreedy 0.000098
# eps 22,reward 80,egreedy 0.000098
# eps 23,reward 81,egreedy 0.000098
# eps 24,reward 80,egreedy 0.000098
# eps 25,reward 81,egreedy 0.000098
# eps 26,reward 81,egreedy 0.000098
# eps 27,reward 81,egreedy 0.000098
# eps 28,reward 81,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 81,egreedy 0.000098
# eps 30,reward 80,egreedy 0.000098
# eps 31,reward 81,egreedy 0.000098
# eps 32,reward 81,egreedy 0.000098
# eps 33,reward 80,egreedy 0.000098
# eps 34,reward 81,egreedy 0.000098
# eps 35,reward 80,egreedy 0.000098
# eps 36,reward 81,egreedy 0.000098
# eps 37,reward 81,egreedy 0.000098
# eps 38,reward 81,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 81,egreedy 0.000098
# eps 40,reward 79,egreedy 0.000098
# eps 41,reward 81,egreedy 0.000098
# eps 42,reward 81,egreedy 0.000098
# eps 43,reward 80,egreedy 0.000098
# eps 44,reward 80,egreedy 0.000098
# eps 45,reward 80,egreedy 0.000098
# eps 46,reward 80,egreedy 0.000098
# eps 47,reward 81,egreedy 0.000098
# eps 48,reward 80,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 81,egreedy 0.000098
# i=9: w_volte 0.700000, w_urllc 0.150000, w_video 0.150000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 29,egreedy 0.050000
# eps 1,reward 30,egreedy 0.025000
# eps 2,reward 27,egreedy 0.012500
# eps 3,reward 26,egreedy 0.006250
# eps 4,reward 26,egreedy 0.003125
# eps 5,reward 69,egreedy 0.001563
# eps 6,reward 77,egreedy 0.000781
# eps 7,reward 82,egreedy 0.000391
# eps 8,reward 82,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 82,egreedy 0.000098
# eps 10,reward 81,egreedy 0.000098
# eps 11,reward 82,egreedy 0.000098
# eps 12,reward 82,egreedy 0.000098
# eps 13,reward 82,egreedy 0.000098
# eps 14,reward 82,egreedy 0.000098
# eps 15,reward 82,egreedy 0.000098
# eps 16,reward 82,egreedy 0.000098
# eps 17,reward 81,egreedy 0.000098
# eps 18,reward 82,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 82,egreedy 0.000098
# eps 20,reward 81,egreedy 0.000098
# eps 21,reward 82,egreedy 0.000098
# eps 22,reward 82,egreedy 0.000098
# eps 23,reward 82,egreedy 0.000098
# eps 24,reward 82,egreedy 0.000098
# eps 25,reward 82,egreedy 0.000098
# eps 26,reward 82,egreedy 0.000098
# eps 27,reward 82,egreedy 0.000098
# eps 28,reward 82,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 82,egreedy 0.000098
# eps 30,reward 82,egreedy 0.000098
# eps 31,reward 82,egreedy 0.000098
# eps 32,reward 82,egreedy 0.000098
# eps 33,reward 82,egreedy 0.000098
# eps 34,reward 82,egreedy 0.000098
# eps 35,reward 82,egreedy 0.000098
# eps 36,reward 82,egreedy 0.000098
# eps 37,reward 82,egreedy 0.000098
# eps 38,reward 82,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 81,egreedy 0.000098
# eps 40,reward 82,egreedy 0.000098
# eps 41,reward 82,egreedy 0.000098
# eps 42,reward 82,egreedy 0.000098
# eps 43,reward 81,egreedy 0.000098
# eps 44,reward 82,egreedy 0.000098
# eps 45,reward 82,egreedy 0.000098
# eps 46,reward 81,egreedy 0.000098
# eps 47,reward 82,egreedy 0.000098
# eps 48,reward 82,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 81,egreedy 0.000098
# i=0: w_volte 0.100000, w_urllc 0.350000, w_video 0.550000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 35,egreedy 0.050000
# eps 1,reward 34,egreedy 0.025000
# eps 2,reward 34,egreedy 0.012500
# eps 3,reward 34,egreedy 0.006250
# eps 4,reward 34,egreedy 0.003125
# eps 5,reward 52,egreedy 0.001563
# eps 6,reward 57,egreedy 0.000781
# eps 7,reward 61,egreedy 0.000391
# eps 8,reward 63,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 63,egreedy 0.000098
# eps 10,reward 63,egreedy 0.000098
# eps 11,reward 63,egreedy 0.000098
# eps 12,reward 63,egreedy 0.000098
# eps 13,reward 63,egreedy 0.000098
# eps 14,reward 63,egreedy 0.000098
# eps 15,reward 63,egreedy 0.000098
# eps 16,reward 63,egreedy 0.000098
# eps 17,reward 63,egreedy 0.000098
# eps 18,reward 63,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 63,egreedy 0.000098
# eps 20,reward 63,egreedy 0.000098
# eps 21,reward 63,egreedy 0.000098
# eps 22,reward 63,egreedy 0.000098
# eps 23,reward 63,egreedy 0.000098
# eps 24,reward 63,egreedy 0.000098
# eps 25,reward 63,egreedy 0.000098
# eps 26,reward 63,egreedy 0.000098
# eps 27,reward 63,egreedy 0.000098
# eps 28,reward 63,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 63,egreedy 0.000098
# eps 30,reward 63,egreedy 0.000098
# eps 31,reward 63,egreedy 0.000098
# eps 32,reward 63,egreedy 0.000098
# eps 33,reward 63,egreedy 0.000098
# eps 34,reward 63,egreedy 0.000098
# eps 35,reward 63,egreedy 0.000098
# eps 36,reward 63,egreedy 0.000098
# eps 37,reward 63,egreedy 0.000098
# eps 38,reward 63,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 63,egreedy 0.000098
# eps 40,reward 63,egreedy 0.000098
# eps 41,reward 63,egreedy 0.000098
# eps 42,reward 63,egreedy 0.000098
# eps 43,reward 63,egreedy 0.000098
# eps 44,reward 63,egreedy 0.000098
# eps 45,reward 63,egreedy 0.000098
# eps 46,reward 63,egreedy 0.000098
# eps 47,reward 63,egreedy 0.000098
# eps 48,reward 63,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 63,egreedy 0.000098
# i=1: w_volte 0.100000, w_urllc 0.650000, w_video 0.250000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 60,egreedy 0.050000
# eps 1,reward 60,egreedy 0.025000
# eps 2,reward 61,egreedy 0.012500
# eps 3,reward 63,egreedy 0.006250
# eps 4,reward 63,egreedy 0.003125
# eps 5,reward 57,egreedy 0.001563
# eps 6,reward 61,egreedy 0.000781
# eps 7,reward 58,egreedy 0.000391
# eps 8,reward 62,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 63,egreedy 0.000098
# eps 10,reward 63,egreedy 0.000098
# eps 11,reward 63,egreedy 0.000098
# eps 12,reward 63,egreedy 0.000098
# eps 13,reward 63,egreedy 0.000098
# eps 14,reward 63,egreedy 0.000098
# eps 15,reward 63,egreedy 0.000098
# eps 16,reward 63,egreedy 0.000098
# eps 17,reward 63,egreedy 0.000098
# eps 18,reward 63,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 63,egreedy 0.000098
# eps 20,reward 63,egreedy 0.000098
# eps 21,reward 63,egreedy 0.000098
# eps 22,reward 63,egreedy 0.000098
# eps 23,reward 63,egreedy 0.000098
# eps 24,reward 63,egreedy 0.000098
# eps 25,reward 63,egreedy 0.000098
# eps 26,reward 63,egreedy 0.000098
# eps 27,reward 61,egreedy 0.000098
# eps 28,reward 58,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 63,egreedy 0.000098
# eps 30,reward 63,egreedy 0.000098
# eps 31,reward 63,egreedy 0.000098
# eps 32,reward 63,egreedy 0.000098
# eps 33,reward 63,egreedy 0.000098
# eps 34,reward 63,egreedy 0.000098
# eps 35,reward 63,egreedy 0.000098
# eps 36,reward 63,egreedy 0.000098
# eps 37,reward 63,egreedy 0.000098
# eps 38,reward 63,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 63,egreedy 0.000098
# eps 40,reward 63,egreedy 0.000098
# eps 41,reward 63,egreedy 0.000098
# eps 42,reward 63,egreedy 0.000098
# eps 43,reward 63,egreedy 0.000098
# eps 44,reward 63,egreedy 0.000098
# eps 45,reward 63,egreedy 0.000098
# eps 46,reward 63,egreedy 0.000098
# eps 47,reward 63,egreedy 0.000098
# eps 48,reward 63,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 63,egreedy 0.000098
# i=2: w_volte 0.300000, w_urllc 0.150000, w_video 0.550000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 21,egreedy 0.050000
# eps 1,reward 21,egreedy 0.025000
# eps 2,reward 20,egreedy 0.012500
# eps 3,reward 19,egreedy 0.006250
# eps 4,reward 19,egreedy 0.003125
# eps 5,reward 62,egreedy 0.001563
# eps 6,reward 77,egreedy 0.000781
# eps 7,reward 77,egreedy 0.000391
# eps 8,reward 77,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 77,egreedy 0.000098
# eps 10,reward 77,egreedy 0.000098
# eps 11,reward 77,egreedy 0.000098
# eps 12,reward 77,egreedy 0.000098
# eps 13,reward 77,egreedy 0.000098
# eps 14,reward 77,egreedy 0.000098
# eps 15,reward 77,egreedy 0.000098
# eps 16,reward 77,egreedy 0.000098
# eps 17,reward 77,egreedy 0.000098
# eps 18,reward 77,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 77,egreedy 0.000098
# eps 20,reward 77,egreedy 0.000098
# eps 21,reward 77,egreedy 0.000098
# eps 22,reward 77,egreedy 0.000098
# eps 23,reward 77,egreedy 0.000098
# eps 24,reward 77,egreedy 0.000098
# eps 25,reward 77,egreedy 0.000098
# eps 26,reward 77,egreedy 0.000098
# eps 27,reward 77,egreedy 0.000098
# eps 28,reward 77,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 77,egreedy 0.000098
# eps 30,reward 77,egreedy 0.000098
# eps 31,reward 77,egreedy 0.000098
# eps 32,reward 77,egreedy 0.000098
# eps 33,reward 77,egreedy 0.000098
# eps 34,reward 77,egreedy 0.000098
# eps 35,reward 77,egreedy 0.000098
# eps 36,reward 77,egreedy 0.000098
# eps 37,reward 77,egreedy 0.000098
# eps 38,reward 77,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 77,egreedy 0.000098
# eps 40,reward 77,egreedy 0.000098
# eps 41,reward 77,egreedy 0.000098
# eps 42,reward 77,egreedy 0.000098
# eps 43,reward 77,egreedy 0.000098
# eps 44,reward 77,egreedy 0.000098
# ...
# eps 38,reward 67,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 66,egreedy 0.000098
# eps 40,reward 66,egreedy 0.000098
# eps 41,reward 67,egreedy 0.000098
# eps 42,reward 67,egreedy 0.000098
# eps 43,reward 67,egreedy 0.000098
# eps 44,reward 67,egreedy 0.000098
# eps 45,reward 66,egreedy 0.000098
# eps 46,reward 66,egreedy 0.000098
# eps 47,reward 66,egreedy 0.000098
# eps 48,reward 66,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 66,egreedy 0.000098
# i=4: w_volte 0.550000, w_urllc 0.200000, w_video 0.250000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 31,egreedy 0.050000
# eps 1,reward 31,egreedy 0.025000
# eps 2,reward 29,egreedy 0.012500
# eps 3,reward 28,egreedy 0.006250
# eps 4,reward 28,egreedy 0.003125
# eps 5,reward 67,egreedy 0.001563
# eps 6,reward 72,egreedy 0.000781
# eps 7,reward 75,egreedy 0.000391
# eps 8,reward 75,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 75,egreedy 0.000098
# eps 10,reward 75,egreedy 0.000098
# eps 11,reward 75,egreedy 0.000098
# eps 12,reward 75,egreedy 0.000098
# eps 13,reward 75,egreedy 0.000098
# eps 14,reward 75,egreedy 0.000098
# eps 15,reward 75,egreedy 0.000098
# eps 16,reward 75,egreedy 0.000098
# eps 17,reward 75,egreedy 0.000098
# eps 18,reward 75,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 75,egreedy 0.000098
# eps 20,reward 75,egreedy 0.000098
# eps 21,reward 75,egreedy 0.000098
# eps 22,reward 75,egreedy 0.000098
# eps 23,reward 75,egreedy 0.000098
# eps 24,reward 75,egreedy 0.000098
# eps 25,reward 75,egreedy 0.000098
# eps 26,reward 75,egreedy 0.000098
# eps 27,reward 75,egreedy 0.000098
# eps 28,reward 75,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 75,egreedy 0.000098
# eps 30,reward 75,egreedy 0.000098
# eps 31,reward 75,egreedy 0.000098
# eps 32,reward 75,egreedy 0.000098
# eps 33,reward 75,egreedy 0.000098
# eps 34,reward 75,egreedy 0.000098
# eps 35,reward 75,egreedy 0.000098
# eps 36,reward 75,egreedy 0.000098
# eps 37,reward 75,egreedy 0.000098
# eps 38,reward 75,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 75,egreedy 0.000098
# eps 40,reward 75,egreedy 0.000098
# eps 41,reward 75,egreedy 0.000098
# eps 42,reward 75,egreedy 0.000098
# eps 43,reward 75,egreedy 0.000098
# eps 44,reward 75,egreedy 0.000098
# eps 45,reward 75,egreedy 0.000098
# eps 46,reward 75,egreedy 0.000098
# eps 47,reward 75,egreedy 0.000098
# eps 48,reward 75,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 75,egreedy 0.000098
# i=5: w_volte 0.150000, w_urllc 0.400000, w_video 0.450000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 40,egreedy 0.050000
# eps 1,reward 39,egreedy 0.025000
# eps 2,reward 40,egreedy 0.012500
# eps 3,reward 40,egreedy 0.006250
# eps 4,reward 40,egreedy 0.003125
# eps 5,reward 48,egreedy 0.001563
# eps 6,reward 51,egreedy 0.000781
# eps 7,reward 53,egreedy 0.000391
# eps 8,reward 53,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 53,egreedy 0.000098
# eps 10,reward 53,egreedy 0.000098
# eps 11,reward 53,egreedy 0.000098
# eps 12,reward 53,egreedy 0.000098
# eps 13,reward 53,egreedy 0.000098
# eps 14,reward 53,egreedy 0.000098
# eps 15,reward 53,egreedy 0.000098
# eps 16,reward 53,egreedy 0.000098
# eps 17,reward 53,egreedy 0.000098
# eps 18,reward 53,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 53,egreedy 0.000098
# eps 20,reward 53,egreedy 0.000098
# eps 21,reward 53,egreedy 0.000098
# eps 22,reward 53,egreedy 0.000098
# eps 23,reward 53,egreedy 0.000098
# eps 24,reward 53,egreedy 0.000098
# eps 25,reward 53,egreedy 0.000098
# eps 26,reward 53,egreedy 0.000098
# eps 27,reward 53,egreedy 0.000098
# eps 28,reward 53,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 54,egreedy 0.000098
# eps 30,reward 54,egreedy 0.000098
# eps 31,reward 54,egreedy 0.000098
# eps 32,reward 54,egreedy 0.000098
# eps 33,reward 55,egreedy 0.000098
# eps 34,reward 55,egreedy 0.000098
# eps 35,reward 55,egreedy 0.000098
# eps 36,reward 55,egreedy 0.000098
# eps 37,reward 55,egreedy 0.000098
# eps 38,reward 54,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 55,egreedy 0.000098
# eps 40,reward 55,egreedy 0.000098
# eps 41,reward 55,egreedy 0.000098
# eps 42,reward 55,egreedy 0.000098
# eps 43,reward 55,egreedy 0.000098
# eps 44,reward 55,egreedy 0.000098
# eps 45,reward 55,egreedy 0.000098
# eps 46,reward 55,egreedy 0.000098
# eps 47,reward 55,egreedy 0.000098
# eps 48,reward 55,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 55,egreedy 0.000098
# i=6: w_volte 0.150000, w_urllc 0.500000, w_video 0.350000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 48,egreedy 0.050000
# eps 1,reward 48,egreedy 0.025000
# eps 2,reward 49,egreedy 0.012500
# eps 3,reward 50,egreedy 0.006250
# eps 4,reward 50,egreedy 0.003125
# eps 5,reward 44,egreedy 0.001563
# eps 6,reward 48,egreedy 0.000781
# eps 7,reward 45,egreedy 0.000391
# eps 8,reward 48,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 49,egreedy 0.000098
# eps 10,reward 49,egreedy 0.000098
# eps 11,reward 48,egreedy 0.000098
# eps 12,reward 49,egreedy 0.000098
# eps 13,reward 50,egreedy 0.000098
# eps 14,reward 49,egreedy 0.000098
# eps 15,reward 49,egreedy 0.000098
# eps 16,reward 49,egreedy 0.000098
# eps 17,reward 49,egreedy 0.000098
# eps 18,reward 49,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 49,egreedy 0.000098
# eps 20,reward 49,egreedy 0.000098
# eps 21,reward 49,egreedy 0.000098
# eps 22,reward 50,egreedy 0.000098
# eps 23,reward 49,egreedy 0.000098
# eps 24,reward 49,egreedy 0.000098
# eps 25,reward 49,egreedy 0.000098
# eps 26,reward 49,egreedy 0.000098
# eps 27,reward 49,egreedy 0.000098
# eps 28,reward 49,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 49,egreedy 0.000098
# eps 30,reward 49,egreedy 0.000098
# eps 31,reward 48,egreedy 0.000098
# eps 32,reward 49,egreedy 0.000098
# eps 33,reward 50,egreedy 0.000098
# eps 34,reward 48,egreedy 0.000098
# eps 35,reward 49,egreedy 0.000098
# eps 36,reward 49,egreedy 0.000098
# eps 37,reward 49,egreedy 0.000098
# eps 38,reward 50,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 50,egreedy 0.000098
# eps 40,reward 49,egreedy 0.000098
# eps 41,reward 49,egreedy 0.000098
# eps 42,reward 49,egreedy 0.000098
# eps 43,reward 49,egreedy 0.000098
# eps 44,reward 49,egreedy 0.000098
# eps 45,reward 49,egreedy 0.000098
# eps 46,reward 49,egreedy 0.000098
# eps 47,reward 49,egreedy 0.000098
# eps 48,reward 48,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 43,egreedy 0.000098
# i=7: w_volte 0.450000, w_urllc 0.100000, w_video 0.450000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 20,egreedy 0.050000
# eps 1,reward 20,egreedy 0.025000
# eps 2,reward 18,egreedy 0.012500
# eps 3,reward 17,egreedy 0.006250
# eps 4,reward 17,egreedy 0.003125
# eps 5,reward 70,egreedy 0.001563
# eps 6,reward 76,egreedy 0.000781
# eps 7,reward 83,egreedy 0.000391
# eps 8,reward 83,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 83,egreedy 0.000098
# eps 10,reward 83,egreedy 0.000098
# eps 11,reward 83,egreedy 0.000098
# eps 12,reward 83,egreedy 0.000098
# eps 13,reward 83,egreedy 0.000098
# eps 14,reward 83,egreedy 0.000098
# eps 15,reward 83,egreedy 0.000098
# eps 16,reward 83,egreedy 0.000098
# eps 17,reward 83,egreedy 0.000098
# eps 18,reward 83,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 83,egreedy 0.000098
# eps 20,reward 83,egreedy 0.000098
# eps 21,reward 83,egreedy 0.000098
# eps 22,reward 83,egreedy 0.000098
# eps 23,reward 83,egreedy 0.000098
# eps 24,reward 83,egreedy 0.000098
# eps 25,reward 83,egreedy 0.000098
# eps 26,reward 83,egreedy 0.000098
# eps 27,reward 83,egreedy 0.000098
# eps 28,reward 83,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 83,egreedy 0.000098
# eps 30,reward 83,egreedy 0.000098
# eps 31,reward 83,egreedy 0.000098
# eps 32,reward 83,egreedy 0.000098
# eps 33,reward 83,egreedy 0.000098
# eps 34,reward 83,egreedy 0.000098
# eps 35,reward 83,egreedy 0.000098
# eps 36,reward 83,egreedy 0.000098
# eps 37,reward 83,egreedy 0.000098
# eps 38,reward 83,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 83,egreedy 0.000098
# eps 40,reward 83,egreedy 0.000098
# eps 41,reward 83,egreedy 0.000098
# eps 42,reward 83,egreedy 0.000098
# eps 43,reward 83,egreedy 0.000098
# eps 44,reward 83,egreedy 0.000098
# eps 45,reward 83,egreedy 0.000098
# eps 46,reward 83,egreedy 0.000098
# eps 47,reward 83,egreedy 0.000098
# eps 48,reward 83,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 83,egreedy 0.000098
# i=8: w_volte 0.450000, w_urllc 0.500000, w_video 0.050000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 54,egreedy 0.050000
# eps 1,reward 55,egreedy 0.025000
# eps 2,reward 54,egreedy 0.012500
# eps 3,reward 55,egreedy 0.006250
# eps 4,reward 55,egreedy 0.003125
# eps 5,reward 66,egreedy 0.001563
# eps 6,reward 70,egreedy 0.000781
# eps 7,reward 72,egreedy 0.000391
# eps 8,reward 73,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 73,egreedy 0.000098
# eps 10,reward 73,egreedy 0.000098
# eps 11,reward 73,egreedy 0.000098
# eps 12,reward 73,egreedy 0.000098
# eps 13,reward 73,egreedy 0.000098
# eps 14,reward 73,egreedy 0.000098
# eps 15,reward 73,egreedy 0.000098
# eps 16,reward 72,egreedy 0.000098
# eps 17,reward 73,egreedy 0.000098
# eps 18,reward 73,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 73,egreedy 0.000098
# eps 20,reward 73,egreedy 0.000098
# eps 21,reward 73,egreedy 0.000098
# eps 22,reward 73,egreedy 0.000098
# eps 23,reward 73,egreedy 0.000098
# eps 24,reward 73,egreedy 0.000098
# eps 25,reward 73,egreedy 0.000098
# eps 26,reward 73,egreedy 0.000098
# eps 27,reward 72,egreedy 0.000098
# eps 28,reward 73,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 73,egreedy 0.000098
# eps 30,reward 73,egreedy 0.000098
# eps 31,reward 73,egreedy 0.000098
# eps 32,reward 73,egreedy 0.000098
# eps 33,reward 73,egreedy 0.000098
# eps 34,reward 73,egreedy 0.000098
# eps 35,reward 73,egreedy 0.000098
# eps 36,reward 73,egreedy 0.000098
# eps 37,reward 73,egreedy 0.000098
# eps 38,reward 73,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 73,egreedy 0.000098
# eps 40,reward 65,egreedy 0.000098
# eps 41,reward 68,egreedy 0.000098
# eps 42,reward 73,egreedy 0.000098
# eps 43,reward 71,egreedy 0.000098
# eps 44,reward 71,egreedy 0.000098
# eps 45,reward 72,egreedy 0.000098
# eps 46,reward 73,egreedy 0.000098
# eps 47,reward 73,egreedy 0.000098
# eps 48,reward 73,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 73,egreedy 0.000098
# i=9: w_volte 0.550000, w_urllc 0.400000, w_video 0.050000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 48,egreedy 0.050000
# eps 1,reward 48,egreedy 0.025000
# eps 2,reward 47,egreedy 0.012500
# eps 3,reward 47,egreedy 0.006250
# eps 4,reward 47,egreedy 0.003125
# eps 5,reward 69,egreedy 0.001563
# eps 6,reward 74,egreedy 0.000781
# eps 7,reward 76,egreedy 0.000391
# eps 8,reward 75,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 75,egreedy 0.000098
# eps 10,reward 76,egreedy 0.000098
# eps 11,reward 76,egreedy 0.000098
# eps 12,reward 76,egreedy 0.000098
# eps 13,reward 76,egreedy 0.000098
# eps 14,reward 76,egreedy 0.000098
# eps 15,reward 76,egreedy 0.000098
# eps 16,reward 76,egreedy 0.000098
# eps 17,reward 76,egreedy 0.000098
# eps 18,reward 76,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 76,egreedy 0.000098
# eps 20,reward 76,egreedy 0.000098
# eps 21,reward 76,egreedy 0.000098
# eps 22,reward 76,egreedy 0.000098
# eps 23,reward 76,egreedy 0.000098
# eps 24,reward 76,egreedy 0.000098
# eps 25,reward 76,egreedy 0.000098
# eps 26,reward 75,egreedy 0.000098
# eps 27,reward 76,egreedy 0.000098
# eps 28,reward 76,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 76,egreedy 0.000098
# eps 30,reward 74,egreedy 0.000098
# eps 31,reward 76,egreedy 0.000098
# eps 32,reward 76,egreedy 0.000098
# eps 33,reward 76,egreedy 0.000098
# eps 34,reward 76,egreedy 0.000098
# eps 35,reward 76,egreedy 0.000098
# eps 36,reward 76,egreedy 0.000098
# eps 37,reward 75,egreedy 0.000098
# eps 38,reward 76,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 76,egreedy 0.000098
# eps 40,reward 76,egreedy 0.000098
# eps 41,reward 76,egreedy 0.000098
# eps 42,reward 76,egreedy 0.000098
# eps 43,reward 75,egreedy 0.000098
# eps 44,reward 76,egreedy 0.000098
# eps 45,reward 72,egreedy 0.000098
# eps 46,reward 72,egreedy 0.000098
# eps 47,reward 75,egreedy 0.000098
# eps 48,reward 76,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 75,egreedy 0.000098
# i=0: w_volte 0.550000, w_urllc 0.100000, w_video 0.350000
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 22,egreedy 0.050000
# eps 1,reward 22,egreedy 0.025000
# eps 2,reward 20,egreedy 0.012500
# eps 3,reward 19,egreedy 0.006250
# eps 4,reward 19,egreedy 0.003125
# eps 5,reward 73,egreedy 0.001563
# eps 6,reward 78,egreedy 0.000781
# eps 7,reward 84,egreedy 0.000391
# eps 8,reward 84,egreedy 0.000195
# target network parameters replaced
# eps 9,reward 84,egreedy 0.000098
# eps 10,reward 84,egreedy 0.000098
# eps 11,reward 84,egreedy 0.000098
# eps 12,reward 84,egreedy 0.000098
# eps 13,reward 84,egreedy 0.000098
# eps 14,reward 84,egreedy 0.000098
# eps 15,reward 84,egreedy 0.000098
# eps 16,reward 84,egreedy 0.000098
# eps 17,reward 84,egreedy 0.000098
# eps 18,reward 84,egreedy 0.000098
# target network parameters replaced
# eps 19,reward 84,egreedy 0.000098
# eps 20,reward 84,egreedy 0.000098
# eps 21,reward 84,egreedy 0.000098
# eps 22,reward 84,egreedy 0.000098
# eps 23,reward 84,egreedy 0.000098
# eps 24,reward 84,egreedy 0.000098
# eps 25,reward 84,egreedy 0.000098
# eps 26,reward 84,egreedy 0.000098
# eps 27,reward 84,egreedy 0.000098
# eps 28,reward 84,egreedy 0.000098
# target network parameters replaced
# eps 29,reward 84,egreedy 0.000098
# eps 30,reward 84,egreedy 0.000098
# eps 31,reward 84,egreedy 0.000098
# eps 32,reward 84,egreedy 0.000098
# eps 33,reward 84,egreedy 0.000098
# eps 34,reward 84,egreedy 0.000098
# eps 35,reward 84,egreedy 0.000098
# eps 36,reward 84,egreedy 0.000098
# eps 37,reward 84,egreedy 0.000098
# eps 38,reward 84,egreedy 0.000098
# target network parameters replaced
# eps 39,reward 84,egreedy 0.000098
# eps 40,reward 84,egreedy 0.000098
# eps 41,reward 84,egreedy 0.000098
# eps 42,reward 84,egreedy 0.000098
# eps 43,reward 84,egreedy 0.000098
# eps 44,reward 84,egreedy 0.000098
# eps 45,reward 84,egreedy 0.000098
# eps 46,reward 84,egreedy 0.000098
# eps 47,reward 84,egreedy 0.000098
# eps 48,reward 84,egreedy 0.000098
# target network parameters replaced
# eps 49,reward 84,egreedy 0.000098
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-19833b422b54> in <module>
#      14     for i in range(0,10):
#      15         # set the weights of the learner agent's reward function
# ---> 16         w_volte = utils.get_reward_weights_acc(i, order)[0]
#      17         w_urllc = utils.get_reward_weights_acc(i, order)[1]
#      18         w_video = utils.get_reward_weights_acc(i, order)[2]
#
# ~/workspace/M2DQN/lib/utils.py in get_reward_weights_acc(seed, order)
#      40 def get_reward_weights_acc(seed, order):
#      41     weights_set = seed+(order*10)
# ---> 42     return weights_for_acc[weights_set]
#      43
#      44 def generate_data(num_users_volte, num_users_video, num_users_urllc, num_tti):
#
# IndexError: list index out of range
