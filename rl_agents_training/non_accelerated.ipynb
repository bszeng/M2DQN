# %% [markdown]
# # non_accelerate

# %% [markdown]
# ### import required packages

# %%
##################### import required packages ##################### 


import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os

import sys
if "../" not in sys.path:
    sys.path.append("../")

from lib.envs.slicing_env import SlicingEnvironment
from lib.agents import dqn 
from lib import utils

matplotlib.style.use('ggplot')


##################### configure the simulation ##################### 

# set a random seed for reproducibility
np.random.seed(2023)

# number of DRL agent timesteps per episode 
max_episode_timesteps = 100

total_data_episodes = 1

# number of DRL agent episodes (for the sake of better results visulization)
total_episodes = 50

# qlearning or sarsa1
agent_name = 'dqn'

learning_type = 'non_accelerated'

# sigmoid reward function configurations
c1_volte = 0.5
c2_volte = 10
c1_urllc = 2
c2_urllc = 3
c1_video = 1
c2_video = 7

# q-learning agent configurations
exploration = 'e_greedy' # 'e_greedy' or 'boltzmann'
discount_factor=0.3
alpha=0.1
epsilon=0.9
epsilon_decay=0.9
decay_steps=50

# policy reuse flag
loaded_qnet='no'

# slicing configurations
# number of users per slice in the following order: VoLTE, Video, URLLC
num_users = [int(46/4), int(46/4), int(8/4)]

poisson_volte = np.full((1, 200), 1)
poisson_video = np.full((1, 200), 1)
poisson_urllc = np.full((1, 200), 1)

max_num_users = [max(poisson_volte[0]), max(poisson_video[0]), max(poisson_urllc[0])]

num_users_poisson = [poisson_video[0], poisson_volte[0], poisson_urllc[0]]

max_size_per_tti = 40
max_num_packets = 0
max_traffic_percentage = 1
num_action_lvls = 15
num_slices = 3
sl_win_size = 40
time_quantum = 1
max_trans_per_tti = 6

##################### generate sample traffic data #####################

traffic_df = utils.generate_data(max_num_users[0], max_num_users[1], 
                                 max_num_users[2], sl_win_size*max_episode_timesteps)
traffic_df = traffic_df.reset_index(drop=True)

# %% [markdown]
# ## Training phase

# %%
# train learner agents using the first batch of reward function weights

order = 0
for i in range(0,10):
    # set the weights of the reward function
    w_volte = utils.get_reward_weights_acc(i, order)[0]
    w_urllc = utils.get_reward_weights_acc(i, order)[1]
    w_video = utils.get_reward_weights_acc(i, order)[2]

    print('i=%d: w_volte %f, w_urllc %f, w_video %f' %(i, w_volte, w_urllc, w_video))

    # initialize the OpenAI gym-compatible environment using the configured simulation parameters
    enviro = SlicingEnvironment(traffic_df, max_num_packets, max_size_per_tti, num_action_lvls, 
                         num_slices, max_episode_timesteps, sl_win_size, time_quantum,total_data_episodes,
                         num_users_poisson, max_traffic_percentage, max_trans_per_tti, w_volte, w_urllc,
                            w_video, c1_volte, c1_urllc, c1_video, c2_volte, c2_urllc, c2_video)

    env = enviro

    ##################### train the basic expert agents from scratch given the configured reward function weights
    qnet, stats = dqn.dqn(env,num_episodes=total_episodes,\
                          exploration=exploration,\
                          gamma=discount_factor,\
                          lr=alpha,\
                          epsilon=epsilon,\
                          epsilon_decay=epsilon_decay,\
                          decay_steps=decay_steps,\
                          loaded_qnet='no')

    # log the trained agents' data
    dictionary = {'config': {'generic': {'max_episode_timesteps': max_episode_timesteps, 'total_episodes': total_episodes,
                         'agent_name': agent_name, 'max_size_per_tti': max_size_per_tti,
                         'max_traffic_percentage': max_traffic_percentage, 'num_action_lvls': num_action_lvls,
                         'num_slices': num_slices, 'sl_win_size': sl_win_size, 'max_trans_per_tti': max_trans_per_tti,
                         'w_volte': w_volte, 'w_urllc': w_urllc, 'w_video': w_video, 'c1_volte': c1_volte,
                         'c2_volte': c2_volte, 'c1_urllc': c1_urllc, 'c2_urllc': c2_urllc,
                         'c1_video': c1_video, 'c2_video': c2_video, 'learning_type': learning_type},
                         'agent_specific': {'discount_factor': discount_factor, 'alpha': alpha,
                                            'epsilon': epsilon, 'epsilon_decay': epsilon_decay,
                                            'decay_steps': decay_steps, 'loaded_qnet': loaded_qnet}
                        },
              'rewards': {'steps': env.step_rewards, 'episodes': list(stats[1])},
              'KPIs': {'delay': env.total_avg_waiting_times,
                       'throughput': env.total_throughputs, 'finished_throughput': env.finished_throughputs,
                       'remaining_sizes_sum': env.remaining_sizes_sum, 'remaining_sizes': env.remaining_sizes,
                       'remaining_times_sum': env.remaining_times_sum, 'remaining_times': env.remaining_times,
                       'total_p_numbers': env.total_p_numbers, 'done_p_numbers': env.done_p_numbers
                     }}

    # save training data to file
    path = 'saved_models/non_accelerated/'
    if not os.path.exists(path):
        os.makedirs(path)

    file_name = path + str(learning_type) + '_' +\
                str(agent_name) + '_' + str(int(w_volte*100)) + \
                str(int(w_urllc*100)) + str(int(w_video*100)) + '_ep.npy'

    np.save(file_name, dictionary)
# Out:
# i=0: w_volte 0.250000, w_urllc 0.100000, w_video 0.650000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 35,egreedy 0.810000
# eps 1,reward 33,egreedy 0.729000
# eps 2,reward 37,egreedy 0.656100
# eps 3,reward 35,egreedy 0.590490
# eps 4,reward 32,egreedy 0.531441
# eps 5,reward 55,egreedy 0.478297
# eps 6,reward 60,egreedy 0.430467
# eps 7,reward 60,egreedy 0.387420
# eps 8,reward 62,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 66,egreedy 0.313811
# eps 10,reward 65,egreedy 0.282430
# eps 11,reward 68,egreedy 0.254187
# eps 12,reward 63,egreedy 0.228768
# eps 13,reward 72,egreedy 0.205891
# eps 14,reward 69,egreedy 0.185302
# eps 15,reward 66,egreedy 0.166772
# eps 16,reward 72,egreedy 0.150095
# eps 17,reward 74,egreedy 0.135085
# eps 18,reward 74,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 75,egreedy 0.109419
# eps 20,reward 76,egreedy 0.098477
# eps 21,reward 73,egreedy 0.088629
# eps 22,reward 74,egreedy 0.079766
# eps 23,reward 77,egreedy 0.071790
# eps 24,reward 77,egreedy 0.064611
# eps 25,reward 74,egreedy 0.058150
# eps 26,reward 76,egreedy 0.052335
# eps 27,reward 78,egreedy 0.047101
# eps 28,reward 78,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 79,egreedy 0.038152
# eps 30,reward 80,egreedy 0.034337
# eps 31,reward 77,egreedy 0.030903
# eps 32,reward 78,egreedy 0.027813
# eps 33,reward 79,egreedy 0.025032
# eps 34,reward 80,egreedy 0.022528
# eps 35,reward 80,egreedy 0.020276
# eps 36,reward 79,egreedy 0.018248
# eps 37,reward 78,egreedy 0.016423
# eps 38,reward 78,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 78,egreedy 0.013303
# eps 40,reward 78,egreedy 0.011973
# eps 41,reward 77,egreedy 0.010775
# eps 42,reward 77,egreedy 0.009698
# eps 43,reward 79,egreedy 0.008728
# eps 44,reward 80,egreedy 0.007855
# eps 45,reward 80,egreedy 0.007070
# eps 46,reward 79,egreedy 0.006363
# eps 47,reward 79,egreedy 0.005726
# eps 48,reward 79,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 79,egreedy 0.004638
# i=1: w_volte 0.250000, w_urllc 0.700000, w_video 0.050000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 41,egreedy 0.810000
# eps 1,reward 43,egreedy 0.729000
# eps 2,reward 42,egreedy 0.656100
# eps 3,reward 46,egreedy 0.590490
# eps 4,reward 51,egreedy 0.531441
# eps 5,reward 53,egreedy 0.478297
# eps 6,reward 53,egreedy 0.430467
# eps 7,reward 56,egreedy 0.387420
# eps 8,reward 57,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 60,egreedy 0.313811
# eps 10,reward 58,egreedy 0.282430
# eps 11,reward 58,egreedy 0.254187
# eps 12,reward 59,egreedy 0.228768
# eps 13,reward 59,egreedy 0.205891
# eps 14,reward 63,egreedy 0.185302
# eps 15,reward 58,egreedy 0.166772
# eps 16,reward 63,egreedy 0.150095
# eps 17,reward 62,egreedy 0.135085
# eps 18,reward 65,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 65,egreedy 0.109419
# eps 20,reward 65,egreedy 0.098477
# eps 21,reward 68,egreedy 0.088629
# eps 22,reward 67,egreedy 0.079766
# eps 23,reward 66,egreedy 0.071790
# eps 24,reward 66,egreedy 0.064611
# eps 25,reward 68,egreedy 0.058150
# eps 26,reward 66,egreedy 0.052335
# eps 27,reward 67,egreedy 0.047101
# eps 28,reward 68,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 67,egreedy 0.038152
# eps 30,reward 67,egreedy 0.034337
# eps 31,reward 67,egreedy 0.030903
# eps 32,reward 65,egreedy 0.027813
# eps 33,reward 68,egreedy 0.025032
# eps 34,reward 63,egreedy 0.022528
# eps 35,reward 67,egreedy 0.020276
# eps 36,reward 67,egreedy 0.018248
# eps 37,reward 69,egreedy 0.016423
# eps 38,reward 68,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 69,egreedy 0.013303
# eps 40,reward 66,egreedy 0.011973
# eps 41,reward 69,egreedy 0.010775
# eps 42,reward 68,egreedy 0.009698
# eps 43,reward 65,egreedy 0.008728
# eps 44,reward 65,egreedy 0.007855
# eps 45,reward 69,egreedy 0.007070
# eps 46,reward 69,egreedy 0.006363
# eps 47,reward 62,egreedy 0.005726
# eps 48,reward 64,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 67,egreedy 0.004638
# i=2: w_volte 0.750000, w_urllc 0.200000, w_video 0.050000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 63,egreedy 0.810000
# eps 1,reward 65,egreedy 0.729000
# eps 2,reward 66,egreedy 0.656100
# eps 3,reward 72,egreedy 0.590490
# eps 4,reward 73,egreedy 0.531441
# eps 5,reward 70,egreedy 0.478297
# eps 6,reward 72,egreedy 0.430467
# eps 7,reward 72,egreedy 0.387420
# eps 8,reward 75,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 77,egreedy 0.313811
# eps 10,reward 74,egreedy 0.282430
# eps 11,reward 76,egreedy 0.254187
# eps 12,reward 77,egreedy 0.228768
# eps 13,reward 78,egreedy 0.205891
# eps 14,reward 79,egreedy 0.185302
# eps 15,reward 78,egreedy 0.166772
# eps 16,reward 80,egreedy 0.150095
# eps 17,reward 80,egreedy 0.135085
# eps 18,reward 81,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 80,egreedy 0.109419
# eps 20,reward 82,egreedy 0.098477
# eps 21,reward 81,egreedy 0.088629
# eps 22,reward 84,egreedy 0.079766
# eps 23,reward 80,egreedy 0.071790
# eps 24,reward 81,egreedy 0.064611
# eps 25,reward 83,egreedy 0.058150
# eps 26,reward 82,egreedy 0.052335
# eps 27,reward 83,egreedy 0.047101
# eps 28,reward 83,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 82,egreedy 0.038152
# eps 30,reward 84,egreedy 0.034337
# eps 31,reward 82,egreedy 0.030903
# eps 32,reward 83,egreedy 0.027813
# eps 33,reward 81,egreedy 0.025032
# eps 34,reward 84,egreedy 0.022528
# eps 35,reward 83,egreedy 0.020276
# eps 36,reward 83,egreedy 0.018248
# eps 37,reward 82,egreedy 0.016423
# eps 38,reward 81,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 83,egreedy 0.013303
# eps 40,reward 80,egreedy 0.011973
# eps 41,reward 82,egreedy 0.010775
# eps 42,reward 82,egreedy 0.009698
# eps 43,reward 81,egreedy 0.008728
# eps 44,reward 81,egreedy 0.007855
# eps 45,reward 83,egreedy 0.007070
# eps 46,reward 83,egreedy 0.006363
# eps 47,reward 82,egreedy 0.005726
# eps 48,reward 83,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 83,egreedy 0.004638
# i=3: w_volte 0.750000, w_urllc 0.100000, w_video 0.150000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 62,egreedy 0.810000
# eps 1,reward 63,egreedy 0.729000
# eps 2,reward 65,egreedy 0.656100
# eps 3,reward 70,egreedy 0.590490
# eps 4,reward 69,egreedy 0.531441
# eps 5,reward 71,egreedy 0.478297
# eps 6,reward 75,egreedy 0.430467
# eps 7,reward 75,egreedy 0.387420
# eps 8,reward 77,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 79,egreedy 0.313811
# eps 10,reward 77,egreedy 0.282430
# eps 11,reward 79,egreedy 0.254187
# eps 12,reward 79,egreedy 0.228768
# eps 13,reward 81,egreedy 0.205891
# eps 14,reward 82,egreedy 0.185302
# eps 15,reward 81,egreedy 0.166772
# eps 16,reward 82,egreedy 0.150095
# eps 17,reward 81,egreedy 0.135085
# eps 18,reward 83,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 82,egreedy 0.109419
# eps 20,reward 85,egreedy 0.098477
# eps 21,reward 82,egreedy 0.088629
# eps 22,reward 85,egreedy 0.079766
# eps 23,reward 83,egreedy 0.071790
# eps 24,reward 84,egreedy 0.064611
# eps 25,reward 84,egreedy 0.058150
# eps 26,reward 84,egreedy 0.052335
# eps 27,reward 85,egreedy 0.047101
# eps 28,reward 84,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 84,egreedy 0.038152
# eps 30,reward 85,egreedy 0.034337
# eps 31,reward 84,egreedy 0.030903
# eps 32,reward 84,egreedy 0.027813
# eps 33,reward 84,egreedy 0.025032
# eps 34,reward 85,egreedy 0.022528
# eps 35,reward 83,egreedy 0.020276
# eps 36,reward 83,egreedy 0.018248
# eps 37,reward 83,egreedy 0.016423
# eps 38,reward 84,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 84,egreedy 0.013303
# eps 40,reward 85,egreedy 0.011973
# eps 41,reward 86,egreedy 0.010775
# eps 42,reward 85,egreedy 0.009698
# eps 43,reward 79,egreedy 0.008728
# eps 44,reward 83,egreedy 0.007855
# eps 45,reward 85,egreedy 0.007070
# eps 46,reward 86,egreedy 0.006363
# eps 47,reward 82,egreedy 0.005726
# eps 48,reward 85,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 77,egreedy 0.004638
# i=4: w_volte 0.150000, w_urllc 0.300000, w_video 0.550000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 31,egreedy 0.810000
# eps 1,reward 31,egreedy 0.729000
# eps 2,reward 33,egreedy 0.656100
# eps 3,reward 32,egreedy 0.590490
# eps 4,reward 31,egreedy 0.531441
# eps 5,reward 45,egreedy 0.478297
# eps 6,reward 48,egreedy 0.430467
# eps 7,reward 49,egreedy 0.387420
# eps 8,reward 49,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 52,egreedy 0.313811
# eps 10,reward 51,egreedy 0.282430
# eps 11,reward 53,egreedy 0.254187
# eps 12,reward 49,egreedy 0.228768
# eps 13,reward 56,egreedy 0.205891
# eps 14,reward 54,egreedy 0.185302
# eps 15,reward 52,egreedy 0.166772
# eps 16,reward 56,egreedy 0.150095
# eps 17,reward 56,egreedy 0.135085
# eps 18,reward 55,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 59,egreedy 0.109419
# eps 20,reward 61,egreedy 0.098477
# eps 21,reward 60,egreedy 0.088629
# eps 22,reward 59,egreedy 0.079766
# eps 23,reward 60,egreedy 0.071790
# eps 24,reward 61,egreedy 0.064611
# eps 25,reward 60,egreedy 0.058150
# eps 26,reward 60,egreedy 0.052335
# eps 27,reward 61,egreedy 0.047101
# eps 28,reward 62,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 62,egreedy 0.038152
# eps 30,reward 61,egreedy 0.034337
# eps 31,reward 59,egreedy 0.030903
# eps 32,reward 60,egreedy 0.027813
# eps 33,reward 58,egreedy 0.025032
# eps 34,reward 61,egreedy 0.022528
# eps 35,reward 58,egreedy 0.020276
# eps 36,reward 59,egreedy 0.018248
# eps 37,reward 61,egreedy 0.016423
# eps 38,reward 60,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 60,egreedy 0.013303
# eps 40,reward 61,egreedy 0.011973
# eps 41,reward 61,egreedy 0.010775
# eps 42,reward 62,egreedy 0.009698
# eps 43,reward 61,egreedy 0.008728
# eps 44,reward 61,egreedy 0.007855
# eps 45,reward 62,egreedy 0.007070
# eps 46,reward 62,egreedy 0.006363
# eps 47,reward 63,egreedy 0.005726
# eps 48,reward 61,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 61,egreedy 0.004638
# i=5: w_volte 0.150000, w_urllc 0.600000, w_video 0.250000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 34,egreedy 0.810000
# eps 1,reward 36,egreedy 0.729000
# eps 2,reward 36,egreedy 0.656100
# eps 3,reward 37,egreedy 0.590490
# eps 4,reward 40,egreedy 0.531441
# eps 5,reward 43,egreedy 0.478297
# eps 6,reward 45,egreedy 0.430467
# eps 7,reward 48,egreedy 0.387420
# eps 8,reward 48,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 50,egreedy 0.313811
# eps 10,reward 49,egreedy 0.282430
# eps 11,reward 49,egreedy 0.254187
# eps 12,reward 46,egreedy 0.228768
# eps 13,reward 51,egreedy 0.205891
# eps 14,reward 51,egreedy 0.185302
# eps 15,reward 49,egreedy 0.166772
# eps 16,reward 51,egreedy 0.150095
# eps 17,reward 54,egreedy 0.135085
# eps 18,reward 53,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 55,egreedy 0.109419
# eps 20,reward 54,egreedy 0.098477
# eps 21,reward 54,egreedy 0.088629
# eps 22,reward 56,egreedy 0.079766
# eps 23,reward 54,egreedy 0.071790
# eps 24,reward 55,egreedy 0.064611
# eps 25,reward 56,egreedy 0.058150
# eps 26,reward 53,egreedy 0.052335
# eps 27,reward 55,egreedy 0.047101
# eps 28,reward 54,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 55,egreedy 0.038152
# eps 30,reward 56,egreedy 0.034337
# eps 31,reward 58,egreedy 0.030903
# eps 32,reward 58,egreedy 0.027813
# eps 33,reward 55,egreedy 0.025032
# eps 34,reward 53,egreedy 0.022528
# eps 35,reward 53,egreedy 0.020276
# eps 36,reward 54,egreedy 0.018248
# eps 37,reward 52,egreedy 0.016423
# eps 38,reward 55,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 55,egreedy 0.013303
# eps 40,reward 57,egreedy 0.011973
# eps 41,reward 55,egreedy 0.010775
# eps 42,reward 55,egreedy 0.009698
# eps 43,reward 54,egreedy 0.008728
# eps 44,reward 57,egreedy 0.007855
# eps 45,reward 53,egreedy 0.007070
# eps 46,reward 57,egreedy 0.006363
# eps 47,reward 58,egreedy 0.005726
# eps 48,reward 51,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 56,egreedy 0.004638
# i=6: w_volte 0.350000, w_urllc 0.100000, w_video 0.550000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 40,egreedy 0.810000
# eps 1,reward 39,egreedy 0.729000
# eps 2,reward 42,egreedy 0.656100
# eps 3,reward 42,egreedy 0.590490
# eps 4,reward 39,egreedy 0.531441
# eps 5,reward 58,egreedy 0.478297
# eps 6,reward 63,egreedy 0.430467
# eps 7,reward 63,egreedy 0.387420
# eps 8,reward 65,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 68,egreedy 0.313811
# eps 10,reward 68,egreedy 0.282430
# eps 11,reward 70,egreedy 0.254187
# eps 12,reward 67,egreedy 0.228768
# eps 13,reward 74,egreedy 0.205891
# eps 14,reward 71,egreedy 0.185302
# eps 15,reward 70,egreedy 0.166772
# eps 16,reward 74,egreedy 0.150095
# eps 17,reward 75,egreedy 0.135085
# eps 18,reward 77,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 76,egreedy 0.109419
# eps 20,reward 78,egreedy 0.098477
# eps 21,reward 75,egreedy 0.088629
# eps 22,reward 77,egreedy 0.079766
# eps 23,reward 78,egreedy 0.071790
# eps 24,reward 80,egreedy 0.064611
# eps 25,reward 76,egreedy 0.058150
# eps 26,reward 79,egreedy 0.052335
# eps 27,reward 79,egreedy 0.047101
# eps 28,reward 80,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 80,egreedy 0.038152
# eps 30,reward 81,egreedy 0.034337
# eps 31,reward 80,egreedy 0.030903
# eps 32,reward 81,egreedy 0.027813
# eps 33,reward 80,egreedy 0.025032
# eps 34,reward 81,egreedy 0.022528
# eps 35,reward 81,egreedy 0.020276
# eps 36,reward 79,egreedy 0.018248
# eps 37,reward 77,egreedy 0.016423
# eps 38,reward 79,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 79,egreedy 0.013303
# eps 40,reward 81,egreedy 0.011973
# eps 41,reward 80,egreedy 0.010775
# eps 42,reward 81,egreedy 0.009698
# eps 43,reward 80,egreedy 0.008728
# eps 44,reward 81,egreedy 0.007855
# eps 45,reward 82,egreedy 0.007070
# eps 46,reward 79,egreedy 0.006363
# eps 47,reward 81,egreedy 0.005726
# eps 48,reward 81,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 81,egreedy 0.004638
# i=7: w_volte 0.350000, w_urllc 0.600000, w_video 0.050000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 45,egreedy 0.810000
# eps 1,reward 47,egreedy 0.729000
# eps 2,reward 47,egreedy 0.656100
# eps 3,reward 51,egreedy 0.590490
# eps 4,reward 55,egreedy 0.531441
# eps 5,reward 55,egreedy 0.478297
# eps 6,reward 55,egreedy 0.430467
# eps 7,reward 57,egreedy 0.387420
# eps 8,reward 59,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 62,egreedy 0.313811
# eps 10,reward 57,egreedy 0.282430
# eps 11,reward 59,egreedy 0.254187
# eps 12,reward 59,egreedy 0.228768
# eps 13,reward 63,egreedy 0.205891
# eps 14,reward 63,egreedy 0.185302
# eps 15,reward 60,egreedy 0.166772
# eps 16,reward 62,egreedy 0.150095
# eps 17,reward 62,egreedy 0.135085
# eps 18,reward 64,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 65,egreedy 0.109419
# eps 20,reward 66,egreedy 0.098477
# eps 21,reward 65,egreedy 0.088629
# eps 22,reward 67,egreedy 0.079766
# eps 23,reward 65,egreedy 0.071790
# eps 24,reward 66,egreedy 0.064611
# eps 25,reward 66,egreedy 0.058150
# eps 26,reward 67,egreedy 0.052335
# eps 27,reward 67,egreedy 0.047101
# eps 28,reward 67,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 66,egreedy 0.038152
# eps 30,reward 64,egreedy 0.034337
# eps 31,reward 65,egreedy 0.030903
# eps 32,reward 65,egreedy 0.027813
# eps 33,reward 64,egreedy 0.025032
# eps 34,reward 67,egreedy 0.022528
# eps 35,reward 63,egreedy 0.020276
# eps 36,reward 61,egreedy 0.018248
# eps 37,reward 64,egreedy 0.016423
# eps 38,reward 68,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 67,egreedy 0.013303
# eps 40,reward 68,egreedy 0.011973
# eps 41,reward 67,egreedy 0.010775
# eps 42,reward 67,egreedy 0.009698
# eps 43,reward 65,egreedy 0.008728
# eps 44,reward 63,egreedy 0.007855
# eps 45,reward 67,egreedy 0.007070
# eps 46,reward 69,egreedy 0.006363
# eps 47,reward 59,egreedy 0.005726
# eps 48,reward 65,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 66,egreedy 0.004638
# i=8: w_volte 0.650000, w_urllc 0.300000, w_video 0.050000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 59,egreedy 0.810000
# eps 1,reward 60,egreedy 0.729000
# eps 2,reward 61,egreedy 0.656100
# eps 3,reward 66,egreedy 0.590490
# eps 4,reward 68,egreedy 0.531441
# eps 5,reward 66,egreedy 0.478297
# eps 6,reward 67,egreedy 0.430467
# eps 7,reward 69,egreedy 0.387420
# eps 8,reward 71,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 73,egreedy 0.313811
# eps 10,reward 69,egreedy 0.282430
# eps 11,reward 72,egreedy 0.254187
# eps 12,reward 73,egreedy 0.228768
# eps 13,reward 74,egreedy 0.205891
# eps 14,reward 75,egreedy 0.185302
# eps 15,reward 73,egreedy 0.166772
# eps 16,reward 74,egreedy 0.150095
# eps 17,reward 74,egreedy 0.135085
# eps 18,reward 74,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 75,egreedy 0.109419
# eps 20,reward 76,egreedy 0.098477
# eps 21,reward 75,egreedy 0.088629
# eps 22,reward 78,egreedy 0.079766
# eps 23,reward 75,egreedy 0.071790
# eps 24,reward 74,egreedy 0.064611
# eps 25,reward 77,egreedy 0.058150
# eps 26,reward 77,egreedy 0.052335
# eps 27,reward 78,egreedy 0.047101
# eps 28,reward 77,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 77,egreedy 0.038152
# eps 30,reward 78,egreedy 0.034337
# eps 31,reward 76,egreedy 0.030903
# eps 32,reward 77,egreedy 0.027813
# eps 33,reward 77,egreedy 0.025032
# eps 34,reward 78,egreedy 0.022528
# eps 35,reward 78,egreedy 0.020276
# eps 36,reward 76,egreedy 0.018248
# eps 37,reward 77,egreedy 0.016423
# eps 38,reward 76,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 78,egreedy 0.013303
# eps 40,reward 78,egreedy 0.011973
# eps 41,reward 78,egreedy 0.010775
# eps 42,reward 72,egreedy 0.009698
# eps 43,reward 78,egreedy 0.008728
# eps 44,reward 78,egreedy 0.007855
# eps 45,reward 78,egreedy 0.007070
# eps 46,reward 77,egreedy 0.006363
# eps 47,reward 78,egreedy 0.005726
# eps 48,reward 78,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 79,egreedy 0.004638
# i=9: w_volte 0.650000, w_urllc 0.100000, w_video 0.250000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 57,egreedy 0.810000
# eps 1,reward 57,egreedy 0.729000
# eps 2,reward 59,egreedy 0.656100
# eps 3,reward 63,egreedy 0.590490
# eps 4,reward 62,egreedy 0.531441
# eps 5,reward 68,egreedy 0.478297
# eps 6,reward 72,egreedy 0.430467
# eps 7,reward 72,egreedy 0.387420
# eps 8,reward 74,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 77,egreedy 0.313811
# eps 10,reward 75,egreedy 0.282430
# eps 11,reward 77,egreedy 0.254187
# eps 12,reward 76,egreedy 0.228768
# eps 13,reward 80,egreedy 0.205891
# eps 14,reward 79,egreedy 0.185302
# eps 15,reward 78,egreedy 0.166772
# eps 16,reward 80,egreedy 0.150095
# eps 17,reward 80,egreedy 0.135085
# eps 18,reward 81,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 81,egreedy 0.109419
# eps 20,reward 83,egreedy 0.098477
# eps 21,reward 81,egreedy 0.088629
# eps 22,reward 83,egreedy 0.079766
# eps 23,reward 81,egreedy 0.071790
# eps 24,reward 83,egreedy 0.064611
# eps 25,reward 84,egreedy 0.058150
# eps 26,reward 83,egreedy 0.052335
# eps 27,reward 84,egreedy 0.047101
# eps 28,reward 84,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 82,egreedy 0.038152
# eps 30,reward 84,egreedy 0.034337
# eps 31,reward 83,egreedy 0.030903
# eps 32,reward 84,egreedy 0.027813
# eps 33,reward 83,egreedy 0.025032
# eps 34,reward 83,egreedy 0.022528
# eps 35,reward 82,egreedy 0.020276
# eps 36,reward 82,egreedy 0.018248
# eps 37,reward 83,egreedy 0.016423
# eps 38,reward 81,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 85,egreedy 0.013303
# eps 40,reward 79,egreedy 0.011973
# eps 41,reward 82,egreedy 0.010775
# eps 42,reward 84,egreedy 0.009698
# eps 43,reward 83,egreedy 0.008728
# eps 44,reward 85,egreedy 0.007855
# eps 45,reward 85,egreedy 0.007070
# eps 46,reward 85,egreedy 0.006363
# eps 47,reward 83,egreedy 0.005726
# eps 48,reward 81,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 84,egreedy 0.004638
# i=0: w_volte 0.250000, w_urllc 0.300000, w_video 0.450000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 37,egreedy 0.810000
# eps 1,reward 37,egreedy 0.729000
# eps 2,reward 39,egreedy 0.656100
# eps 3,reward 39,egreedy 0.590490
# eps 4,reward 38,egreedy 0.531441
# eps 5,reward 47,egreedy 0.478297
# eps 6,reward 51,egreedy 0.430467
# eps 7,reward 52,egreedy 0.387420
# eps 8,reward 52,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 54,egreedy 0.313811
# eps 10,reward 53,egreedy 0.282430
# eps 11,reward 54,egreedy 0.254187
# eps 12,reward 52,egreedy 0.228768
# eps 13,reward 58,egreedy 0.205891
# eps 14,reward 55,egreedy 0.185302
# eps 15,reward 54,egreedy 0.166772
# eps 16,reward 56,egreedy 0.150095
# eps 17,reward 56,egreedy 0.135085
# eps 18,reward 59,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 60,egreedy 0.109419
# eps 20,reward 59,egreedy 0.098477
# eps 21,reward 60,egreedy 0.088629
# eps 22,reward 60,egreedy 0.079766
# eps 23,reward 59,egreedy 0.071790
# eps 24,reward 61,egreedy 0.064611
# eps 25,reward 60,egreedy 0.058150
# eps 26,reward 60,egreedy 0.052335
# eps 27,reward 60,egreedy 0.047101
# eps 28,reward 59,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 59,egreedy 0.038152
# eps 30,reward 61,egreedy 0.034337
# eps 31,reward 62,egreedy 0.030903
# eps 32,reward 62,egreedy 0.027813
# eps 33,reward 61,egreedy 0.025032
# eps 34,reward 60,egreedy 0.022528
# eps 35,reward 57,egreedy 0.020276
# eps 36,reward 59,egreedy 0.018248
# eps 37,reward 61,egreedy 0.016423
# eps 38,reward 61,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 62,egreedy 0.013303
# eps 40,reward 62,egreedy 0.011973
# eps 41,reward 59,egreedy 0.010775
# eps 42,reward 61,egreedy 0.009698
# eps 43,reward 62,egreedy 0.008728
# eps 44,reward 63,egreedy 0.007855
# eps 45,reward 60,egreedy 0.007070
# eps 46,reward 61,egreedy 0.006363
# eps 47,reward 62,egreedy 0.005726
# eps 48,reward 59,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 63,egreedy 0.004638
# i=1: w_volte 0.350000, w_urllc 0.200000, w_video 0.450000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 41,egreedy 0.810000
# eps 1,reward 41,egreedy 0.729000
# eps 2,reward 43,egreedy 0.656100
# eps 3,reward 44,egreedy 0.590490
# eps 4,reward 43,egreedy 0.531441
# eps 5,reward 53,egreedy 0.478297
# eps 6,reward 59,egreedy 0.430467
# eps 7,reward 59,egreedy 0.387420
# eps 8,reward 60,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 63,egreedy 0.313811
# eps 10,reward 62,egreedy 0.282430
# eps 11,reward 64,egreedy 0.254187
# eps 12,reward 61,egreedy 0.228768
# eps 13,reward 67,egreedy 0.205891
# eps 14,reward 66,egreedy 0.185302
# eps 15,reward 63,egreedy 0.166772
# eps 16,reward 67,egreedy 0.150095
# eps 17,reward 68,egreedy 0.135085
# eps 18,reward 69,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 69,egreedy 0.109419
# eps 20,reward 70,egreedy 0.098477
# eps 21,reward 70,egreedy 0.088629
# eps 22,reward 71,egreedy 0.079766
# eps 23,reward 70,egreedy 0.071790
# eps 24,reward 71,egreedy 0.064611
# eps 25,reward 68,egreedy 0.058150
# eps 26,reward 70,egreedy 0.052335
# eps 27,reward 70,egreedy 0.047101
# eps 28,reward 72,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 71,egreedy 0.038152
# eps 30,reward 71,egreedy 0.034337
# eps 31,reward 71,egreedy 0.030903
# eps 32,reward 72,egreedy 0.027813
# eps 33,reward 71,egreedy 0.025032
# eps 34,reward 73,egreedy 0.022528
# eps 35,reward 73,egreedy 0.020276
# eps 36,reward 69,egreedy 0.018248
# eps 37,reward 70,egreedy 0.016423
# eps 38,reward 71,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 73,egreedy 0.013303
# eps 40,reward 72,egreedy 0.011973
# eps 41,reward 71,egreedy 0.010775
# eps 42,reward 72,egreedy 0.009698
# eps 43,reward 72,egreedy 0.008728
# eps 44,reward 73,egreedy 0.007855
# eps 45,reward 72,egreedy 0.007070
# eps 46,reward 67,egreedy 0.006363
# eps 47,reward 71,egreedy 0.005726
# eps 48,reward 72,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 73,egreedy 0.004638
# i=2: w_volte 0.350000, w_urllc 0.500000, w_video 0.150000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 44,egreedy 0.810000
# eps 1,reward 46,egreedy 0.729000
# eps 2,reward 46,egreedy 0.656100
# eps 3,reward 49,egreedy 0.590490
# eps 4,reward 52,egreedy 0.531441
# eps 5,reward 50,egreedy 0.478297
# eps 6,reward 52,egreedy 0.430467
# eps 7,reward 53,egreedy 0.387420
# eps 8,reward 55,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 57,egreedy 0.313811
# eps 10,reward 53,egreedy 0.282430
# eps 11,reward 55,egreedy 0.254187
# eps 12,reward 56,egreedy 0.228768
# eps 13,reward 59,egreedy 0.205891
# eps 14,reward 58,egreedy 0.185302
# eps 15,reward 54,egreedy 0.166772
# eps 16,reward 57,egreedy 0.150095
# eps 17,reward 57,egreedy 0.135085
# eps 18,reward 56,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 60,egreedy 0.109419
# eps 20,reward 59,egreedy 0.098477
# eps 21,reward 60,egreedy 0.088629
# eps 22,reward 59,egreedy 0.079766
# eps 23,reward 59,egreedy 0.071790
# eps 24,reward 59,egreedy 0.064611
# eps 25,reward 61,egreedy 0.058150
# eps 26,reward 59,egreedy 0.052335
# eps 27,reward 60,egreedy 0.047101
# eps 28,reward 62,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 60,egreedy 0.038152
# eps 30,reward 56,egreedy 0.034337
# eps 31,reward 56,egreedy 0.030903
# eps 32,reward 60,egreedy 0.027813
# eps 33,reward 53,egreedy 0.025032
# eps 34,reward 56,egreedy 0.022528
# eps 35,reward 58,egreedy 0.020276
# eps 36,reward 60,egreedy 0.018248
# eps 37,reward 60,egreedy 0.016423
# eps 38,reward 61,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 62,egreedy 0.013303
# eps 40,reward 59,egreedy 0.011973
# eps 41,reward 61,egreedy 0.010775
# eps 42,reward 57,egreedy 0.009698
# eps 43,reward 59,egreedy 0.008728
# eps 44,reward 58,egreedy 0.007855
# eps 45,reward 62,egreedy 0.007070
# eps 46,reward 62,egreedy 0.006363
# eps 47,reward 58,egreedy 0.005726
# eps 48,reward 59,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 58,egreedy 0.004638
# i=3: w_volte 0.550000, w_urllc 0.200000, w_video 0.150000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 50,egreedy 0.810000
# eps 1,reward 51,egreedy 0.729000
# eps 2,reward 52,egreedy 0.656100
# eps 3,reward 56,egreedy 0.590490
# eps 4,reward 57,egreedy 0.531441
# eps 5,reward 56,egreedy 0.478297
# eps 6,reward 58,egreedy 0.430467
# eps 7,reward 59,egreedy 0.387420
# eps 8,reward 59,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 62,egreedy 0.313811
# eps 10,reward 60,egreedy 0.282430
# eps 11,reward 61,egreedy 0.254187
# eps 12,reward 60,egreedy 0.228768
# eps 13,reward 62,egreedy 0.205891
# eps 14,reward 63,egreedy 0.185302
# eps 15,reward 62,egreedy 0.166772
# eps 16,reward 63,egreedy 0.150095
# eps 17,reward 61,egreedy 0.135085
# eps 18,reward 64,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 63,egreedy 0.109419
# eps 20,reward 65,egreedy 0.098477
# eps 21,reward 63,egreedy 0.088629
# eps 22,reward 66,egreedy 0.079766
# eps 23,reward 63,egreedy 0.071790
# eps 24,reward 64,egreedy 0.064611
# eps 25,reward 64,egreedy 0.058150
# eps 26,reward 64,egreedy 0.052335
# eps 27,reward 64,egreedy 0.047101
# eps 28,reward 65,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 64,egreedy 0.038152
# eps 30,reward 63,egreedy 0.034337
# eps 31,reward 63,egreedy 0.030903
# eps 32,reward 64,egreedy 0.027813
# eps 33,reward 63,egreedy 0.025032
# eps 34,reward 65,egreedy 0.022528
# eps 35,reward 64,egreedy 0.020276
# eps 36,reward 63,egreedy 0.018248
# eps 37,reward 64,egreedy 0.016423
# eps 38,reward 63,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 65,egreedy 0.013303
# eps 40,reward 65,egreedy 0.011973
# eps 41,reward 63,egreedy 0.010775
# eps 42,reward 65,egreedy 0.009698
# eps 43,reward 62,egreedy 0.008728
# eps 44,reward 64,egreedy 0.007855
# eps 45,reward 64,egreedy 0.007070
# eps 46,reward 66,egreedy 0.006363
# eps 47,reward 65,egreedy 0.005726
# eps 48,reward 65,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 62,egreedy 0.004638
# i=4: w_volte 0.550000, w_urllc 0.200000, w_video 0.250000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 52,egreedy 0.810000
# eps 1,reward 53,egreedy 0.729000
# eps 2,reward 54,egreedy 0.656100
# eps 3,reward 58,egreedy 0.590490
# eps 4,reward 58,egreedy 0.531441
# eps 5,reward 61,egreedy 0.478297
# eps 6,reward 64,egreedy 0.430467
# eps 7,reward 65,egreedy 0.387420
# eps 8,reward 66,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 68,egreedy 0.313811
# eps 10,reward 66,egreedy 0.282430
# eps 11,reward 68,egreedy 0.254187
# eps 12,reward 67,egreedy 0.228768
# eps 13,reward 71,egreedy 0.205891
# eps 14,reward 70,egreedy 0.185302
# eps 15,reward 68,egreedy 0.166772
# eps 16,reward 71,egreedy 0.150095
# eps 17,reward 71,egreedy 0.135085
# eps 18,reward 72,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 72,egreedy 0.109419
# eps 20,reward 73,egreedy 0.098477
# eps 21,reward 71,egreedy 0.088629
# eps 22,reward 73,egreedy 0.079766
# eps 23,reward 72,egreedy 0.071790
# eps 24,reward 72,egreedy 0.064611
# eps 25,reward 74,egreedy 0.058150
# eps 26,reward 73,egreedy 0.052335
# eps 27,reward 74,egreedy 0.047101
# eps 28,reward 74,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 72,egreedy 0.038152
# eps 30,reward 73,egreedy 0.034337
# eps 31,reward 74,egreedy 0.030903
# eps 32,reward 74,egreedy 0.027813
# eps 33,reward 71,egreedy 0.025032
# eps 34,reward 74,egreedy 0.022528
# eps 35,reward 74,egreedy 0.020276
# eps 36,reward 72,egreedy 0.018248
# eps 37,reward 73,egreedy 0.016423
# eps 38,reward 72,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 74,egreedy 0.013303
# eps 40,reward 70,egreedy 0.011973
# eps 41,reward 73,egreedy 0.010775
# eps 42,reward 72,egreedy 0.009698
# eps 43,reward 74,egreedy 0.008728
# eps 44,reward 74,egreedy 0.007855
# eps 45,reward 73,egreedy 0.007070
# eps 46,reward 67,egreedy 0.006363
# eps 47,reward 73,egreedy 0.005726
# eps 48,reward 71,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 74,egreedy 0.004638
# i=5: w_volte 0.150000, w_urllc 0.400000, w_video 0.450000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 32,egreedy 0.810000
# eps 1,reward 32,egreedy 0.729000
# eps 2,reward 34,egreedy 0.656100
# eps 3,reward 34,egreedy 0.590490
# eps 4,reward 34,egreedy 0.531441
# eps 5,reward 41,egreedy 0.478297
# eps 6,reward 44,egreedy 0.430467
# eps 7,reward 44,egreedy 0.387420
# eps 8,reward 45,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 46,egreedy 0.313811
# eps 10,reward 45,egreedy 0.282430
# eps 11,reward 47,egreedy 0.254187
# eps 12,reward 45,egreedy 0.228768
# eps 13,reward 49,egreedy 0.205891
# eps 14,reward 48,egreedy 0.185302
# eps 15,reward 44,egreedy 0.166772
# eps 16,reward 50,egreedy 0.150095
# eps 17,reward 50,egreedy 0.135085
# eps 18,reward 51,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 52,egreedy 0.109419
# eps 20,reward 52,egreedy 0.098477
# eps 21,reward 52,egreedy 0.088629
# eps 22,reward 51,egreedy 0.079766
# eps 23,reward 51,egreedy 0.071790
# eps 24,reward 53,egreedy 0.064611
# eps 25,reward 52,egreedy 0.058150
# eps 26,reward 50,egreedy 0.052335
# eps 27,reward 52,egreedy 0.047101
# eps 28,reward 51,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 49,egreedy 0.038152
# eps 30,reward 52,egreedy 0.034337
# eps 31,reward 52,egreedy 0.030903
# eps 32,reward 53,egreedy 0.027813
# eps 33,reward 51,egreedy 0.025032
# eps 34,reward 51,egreedy 0.022528
# eps 35,reward 48,egreedy 0.020276
# eps 36,reward 53,egreedy 0.018248
# eps 37,reward 52,egreedy 0.016423
# eps 38,reward 51,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 52,egreedy 0.013303
# eps 40,reward 52,egreedy 0.011973
# eps 41,reward 51,egreedy 0.010775
# eps 42,reward 52,egreedy 0.009698
# eps 43,reward 51,egreedy 0.008728
# eps 44,reward 52,egreedy 0.007855
# eps 45,reward 53,egreedy 0.007070
# eps 46,reward 52,egreedy 0.006363
# eps 47,reward 53,egreedy 0.005726
# eps 48,reward 49,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 53,egreedy 0.004638
# i=6: w_volte 0.150000, w_urllc 0.500000, w_video 0.350000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 33,egreedy 0.810000
# eps 1,reward 34,egreedy 0.729000
# eps 2,reward 35,egreedy 0.656100
# eps 3,reward 35,egreedy 0.590490
# eps 4,reward 37,egreedy 0.531441
# eps 5,reward 38,egreedy 0.478297
# eps 6,reward 40,egreedy 0.430467
# eps 7,reward 41,egreedy 0.387420
# eps 8,reward 41,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 43,egreedy 0.313811
# eps 10,reward 41,egreedy 0.282430
# eps 11,reward 42,egreedy 0.254187
# eps 12,reward 42,egreedy 0.228768
# eps 13,reward 43,egreedy 0.205891
# eps 14,reward 44,egreedy 0.185302
# eps 15,reward 40,egreedy 0.166772
# eps 16,reward 45,egreedy 0.150095
# eps 17,reward 44,egreedy 0.135085
# eps 18,reward 46,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 47,egreedy 0.109419
# eps 20,reward 47,egreedy 0.098477
# eps 21,reward 48,egreedy 0.088629
# eps 22,reward 46,egreedy 0.079766
# eps 23,reward 47,egreedy 0.071790
# eps 24,reward 47,egreedy 0.064611
# eps 25,reward 47,egreedy 0.058150
# eps 26,reward 45,egreedy 0.052335
# eps 27,reward 47,egreedy 0.047101
# eps 28,reward 48,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 47,egreedy 0.038152
# eps 30,reward 47,egreedy 0.034337
# eps 31,reward 47,egreedy 0.030903
# eps 32,reward 47,egreedy 0.027813
# eps 33,reward 48,egreedy 0.025032
# eps 34,reward 48,egreedy 0.022528
# eps 35,reward 43,egreedy 0.020276
# eps 36,reward 44,egreedy 0.018248
# eps 37,reward 47,egreedy 0.016423
# eps 38,reward 47,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 47,egreedy 0.013303
# eps 40,reward 45,egreedy 0.011973
# eps 41,reward 47,egreedy 0.010775
# eps 42,reward 47,egreedy 0.009698
# eps 43,reward 46,egreedy 0.008728
# eps 44,reward 46,egreedy 0.007855
# eps 45,reward 47,egreedy 0.007070
# eps 46,reward 45,egreedy 0.006363
# eps 47,reward 47,egreedy 0.005726
# eps 48,reward 46,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 47,egreedy 0.004638
# i=7: w_volte 0.450000, w_urllc 0.100000, w_video 0.450000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 46,egreedy 0.810000
# eps 1,reward 45,egreedy 0.729000
# eps 2,reward 48,egreedy 0.656100
# eps 3,reward 49,egreedy 0.590490
# eps 4,reward 47,egreedy 0.531441
# eps 5,reward 61,egreedy 0.478297
# eps 6,reward 66,egreedy 0.430467
# eps 7,reward 66,egreedy 0.387420
# eps 8,reward 68,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 71,egreedy 0.313811
# eps 10,reward 71,egreedy 0.282430
# eps 11,reward 73,egreedy 0.254187
# eps 12,reward 70,egreedy 0.228768
# eps 13,reward 76,egreedy 0.205891
# eps 14,reward 74,egreedy 0.185302
# eps 15,reward 72,egreedy 0.166772
# eps 16,reward 76,egreedy 0.150095
# eps 17,reward 77,egreedy 0.135085
# eps 18,reward 78,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 78,egreedy 0.109419
# eps 20,reward 80,egreedy 0.098477
# eps 21,reward 78,egreedy 0.088629
# eps 22,reward 79,egreedy 0.079766
# eps 23,reward 80,egreedy 0.071790
# eps 24,reward 81,egreedy 0.064611
# eps 25,reward 78,egreedy 0.058150
# eps 26,reward 80,egreedy 0.052335
# eps 27,reward 81,egreedy 0.047101
# eps 28,reward 81,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 81,egreedy 0.038152
# eps 30,reward 81,egreedy 0.034337
# eps 31,reward 81,egreedy 0.030903
# eps 32,reward 82,egreedy 0.027813
# eps 33,reward 81,egreedy 0.025032
# eps 34,reward 81,egreedy 0.022528
# eps 35,reward 81,egreedy 0.020276
# eps 36,reward 80,egreedy 0.018248
# eps 37,reward 81,egreedy 0.016423
# eps 38,reward 80,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 83,egreedy 0.013303
# eps 40,reward 82,egreedy 0.011973
# eps 41,reward 81,egreedy 0.010775
# eps 42,reward 82,egreedy 0.009698
# eps 43,reward 81,egreedy 0.008728
# eps 44,reward 83,egreedy 0.007855
# eps 45,reward 82,egreedy 0.007070
# eps 46,reward 82,egreedy 0.006363
# eps 47,reward 83,egreedy 0.005726
# eps 48,reward 81,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 82,egreedy 0.004638
# i=8: w_volte 0.450000, w_urllc 0.500000, w_video 0.050000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 50,egreedy 0.810000
# eps 1,reward 52,egreedy 0.729000
# eps 2,reward 52,egreedy 0.656100
# eps 3,reward 56,egreedy 0.590490
# eps 4,reward 60,egreedy 0.531441
# eps 5,reward 59,egreedy 0.478297
# eps 6,reward 59,egreedy 0.430467
# eps 7,reward 61,egreedy 0.387420
# eps 8,reward 63,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 66,egreedy 0.313811
# eps 10,reward 61,egreedy 0.282430
# eps 11,reward 64,egreedy 0.254187
# eps 12,reward 65,egreedy 0.228768
# eps 13,reward 67,egreedy 0.205891
# eps 14,reward 67,egreedy 0.185302
# eps 15,reward 63,egreedy 0.166772
# eps 16,reward 67,egreedy 0.150095
# eps 17,reward 67,egreedy 0.135085
# eps 18,reward 68,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 69,egreedy 0.109419
# eps 20,reward 69,egreedy 0.098477
# eps 21,reward 68,egreedy 0.088629
# eps 22,reward 70,egreedy 0.079766
# eps 23,reward 69,egreedy 0.071790
# eps 24,reward 69,egreedy 0.064611
# eps 25,reward 69,egreedy 0.058150
# eps 26,reward 69,egreedy 0.052335
# eps 27,reward 66,egreedy 0.047101
# eps 28,reward 64,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 71,egreedy 0.038152
# eps 30,reward 71,egreedy 0.034337
# eps 31,reward 69,egreedy 0.030903
# eps 32,reward 70,egreedy 0.027813
# eps 33,reward 64,egreedy 0.025032
# eps 34,reward 71,egreedy 0.022528
# eps 35,reward 69,egreedy 0.020276
# eps 36,reward 70,egreedy 0.018248
# eps 37,reward 68,egreedy 0.016423
# eps 38,reward 71,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 70,egreedy 0.013303
# eps 40,reward 72,egreedy 0.011973
# eps 41,reward 71,egreedy 0.010775
# eps 42,reward 70,egreedy 0.009698
# eps 43,reward 69,egreedy 0.008728
# eps 44,reward 67,egreedy 0.007855
# eps 45,reward 72,egreedy 0.007070
# eps 46,reward 71,egreedy 0.006363
# eps 47,reward 61,egreedy 0.005726
# eps 48,reward 69,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 72,egreedy 0.004638
# i=9: w_volte 0.550000, w_urllc 0.400000, w_video 0.050000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 54,egreedy 0.810000
# eps 1,reward 56,egreedy 0.729000
# eps 2,reward 56,egreedy 0.656100
# eps 3,reward 61,egreedy 0.590490
# eps 4,reward 64,egreedy 0.531441
# eps 5,reward 61,egreedy 0.478297
# eps 6,reward 63,egreedy 0.430467
# eps 7,reward 65,egreedy 0.387420
# eps 8,reward 67,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 69,egreedy 0.313811
# eps 10,reward 66,egreedy 0.282430
# eps 11,reward 68,egreedy 0.254187
# eps 12,reward 69,egreedy 0.228768
# eps 13,reward 71,egreedy 0.205891
# eps 14,reward 71,egreedy 0.185302
# eps 15,reward 68,egreedy 0.166772
# eps 16,reward 71,egreedy 0.150095
# eps 17,reward 70,egreedy 0.135085
# eps 18,reward 71,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 71,egreedy 0.109419
# eps 20,reward 73,egreedy 0.098477
# eps 21,reward 72,egreedy 0.088629
# eps 22,reward 74,egreedy 0.079766
# eps 23,reward 72,egreedy 0.071790
# eps 24,reward 73,egreedy 0.064611
# eps 25,reward 73,egreedy 0.058150
# eps 26,reward 72,egreedy 0.052335
# eps 27,reward 72,egreedy 0.047101
# eps 28,reward 73,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 73,egreedy 0.038152
# eps 30,reward 72,egreedy 0.034337
# eps 31,reward 72,egreedy 0.030903
# eps 32,reward 74,egreedy 0.027813
# eps 33,reward 73,egreedy 0.025032
# eps 34,reward 74,egreedy 0.022528
# eps 35,reward 74,egreedy 0.020276
# eps 36,reward 74,egreedy 0.018248
# eps 37,reward 73,egreedy 0.016423
# eps 38,reward 72,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 74,egreedy 0.013303
# eps 40,reward 74,egreedy 0.011973
# eps 41,reward 74,egreedy 0.010775
# eps 42,reward 71,egreedy 0.009698
# eps 43,reward 74,egreedy 0.008728
# eps 44,reward 73,egreedy 0.007855
# eps 45,reward 74,egreedy 0.007070
# eps 46,reward 74,egreedy 0.006363
# eps 47,reward 72,egreedy 0.005726
# eps 48,reward 72,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 74,egreedy 0.004638
# i=0: w_volte 0.550000, w_urllc 0.100000, w_video 0.350000
# new qnet
# ------------------------------------
# replay_buffer_size(rbz):20000
# replay_start_size(rsz):500
# batch_size(bs):32
# Target_update(tu):1000
# ------------------------------------
# eps 0,reward 51,egreedy 0.810000
# eps 1,reward 51,egreedy 0.729000
# eps 2,reward 54,egreedy 0.656100
# eps 3,reward 56,egreedy 0.590490
# eps 4,reward 54,egreedy 0.531441
# eps 5,reward 64,egreedy 0.478297
# eps 6,reward 69,egreedy 0.430467
# eps 7,reward 69,egreedy 0.387420
# eps 8,reward 71,egreedy 0.348678
# target network parameters replaced
# eps 9,reward 74,egreedy 0.313811
# eps 10,reward 73,egreedy 0.282430
# eps 11,reward 75,egreedy 0.254187
# eps 12,reward 73,egreedy 0.228768
# eps 13,reward 78,egreedy 0.205891
# eps 14,reward 77,egreedy 0.185302
# eps 15,reward 75,egreedy 0.166772
# eps 16,reward 78,egreedy 0.150095
# eps 17,reward 78,egreedy 0.135085
# eps 18,reward 80,egreedy 0.121577
# target network parameters replaced
# eps 19,reward 80,egreedy 0.109419
# eps 20,reward 82,egreedy 0.098477
# eps 21,reward 80,egreedy 0.088629
# eps 22,reward 81,egreedy 0.079766
# eps 23,reward 81,egreedy 0.071790
# eps 24,reward 82,egreedy 0.064611
# eps 25,reward 80,egreedy 0.058150
# eps 26,reward 81,egreedy 0.052335
# eps 27,reward 82,egreedy 0.047101
# eps 28,reward 83,egreedy 0.042391
# target network parameters replaced
# eps 29,reward 82,egreedy 0.038152
# eps 30,reward 82,egreedy 0.034337
# eps 31,reward 82,egreedy 0.030903
# eps 32,reward 83,egreedy 0.027813
# eps 33,reward 80,egreedy 0.025032
# eps 34,reward 80,egreedy 0.022528
# eps 35,reward 82,egreedy 0.020276
# eps 36,reward 82,egreedy 0.018248
# eps 37,reward 82,egreedy 0.016423
# eps 38,reward 80,egreedy 0.014781
# target network parameters replaced
# eps 39,reward 84,egreedy 0.013303
# eps 40,reward 84,egreedy 0.011973
# eps 41,reward 83,egreedy 0.010775
# eps 42,reward 81,egreedy 0.009698
# eps 43,reward 83,egreedy 0.008728
# eps 44,reward 84,egreedy 0.007855
# eps 45,reward 84,egreedy 0.007070
# eps 46,reward 82,egreedy 0.006363
# eps 47,reward 81,egreedy 0.005726
# eps 48,reward 81,egreedy 0.005154
# target network parameters replaced
# eps 49,reward 83,egreedy 0.004638
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-2aa04fdd6f96> in <module>
#       4     for i in range(0,10):
#       5         # set the weights of the reward function
# ----> 6         w_volte = utils.get_reward_weights_acc(i, order)[0]
#       7         w_urllc = utils.get_reward_weights_acc(i, order)[1]
#       8         w_video = utils.get_reward_weights_acc(i, order)[2]
#
# ~/workspace/M2DQN/lib/utils.py in get_reward_weights_acc(seed, order)
#      40 def get_reward_weights_acc(seed, order):
#      41     weights_set = seed+(order*10)
# ---> 42     return weights_for_acc[weights_set]
#      43
#      44 def generate_data(num_users_volte, num_users_video, num_users_urllc, num_tti):
#
# IndexError: list index out of range
